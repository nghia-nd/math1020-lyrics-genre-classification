# %% [markdown]
# # **MATH2020 - Discrete Mathematics - Mini Project**
# ##### **Project title**: A lyric-based genre classification – A Naïve Bayes approach from naïve students.
# ##### **Team**: Grindset
# ##### **Members**
# - Nguyễn Đại Nghĩa - 20nghia.nd@vinuni.edu.vn
# - Bùi Đức Khánh An – 20an.bdk@vinuni.edu.vn
# - Khau Liên Kiệt – 20kiet.kl@vinuni.edu.vn
# - Vương Đỗ Tuấn Thành – 20thanh.vdt@vinuni.edu.vn

# %% [markdown]
# ---
# The key concept of the project is to implement Naïve Bayes’ Theorem for classifying song into the genres through the lyrics. The work procedure divides into three steps:
# - Handling raw data
# - Featurizing
# - Implementing Naïve Bayes’ Theorem
#
# In terms of raw data handling, the dataset is obtained from [Tmthyjames](https://github.com/tmthyjames/cypher), which contains the song name, the lyrics, the year published, the artist, the genre, etc. The dataset will be pre-processed and featurized into planned datatypes for later uses. Regarding the featurizing, its main function is to calculate the frequency of words in each genre to calculate the likelihood. The third procedure is to apply the Naïve Bayes’ Theorem that gives prediction to the song which likelihood of the genre to be fallen into.

# %% [markdown]
# ### **Step 0: Importing**

# %%
# Import library
import pandas as pd
import numpy as np

import nltk
from nltk import ngrams
nltk.download('wordnet')
from nltk.corpus import stopwords
nltk.download('stopwords')

from nltk.stem import WordNetLemmatizer

from collections import Counter

# Import Google Drive for dataset
from google.colab import drive
drive.mount("/content/drive")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import dataset
data_csv = pd.read_csv("/content/drive/MyDrive/lyrics_classification.csv") # Upload the dataset to the home Drive folder to load
data_csv
# Out:
#                                album  ...    album_genre
# 0        The Johnny Cash Show (1970)  ...            NaN
# 1              Rock the World (2000)  ...  Bubblegum Pop
# 2        The Johnny Cash Show (1970)  ...            NaN
# 3             Recipe for Hate (1993)  ...      Punk Rock
# 4             Punk in Drublic (1994)  ...      Punk Rock
# ...                              ...  ...            ...
# 2778354                         Edit  ...            NaN
# 2778355          The Hangover (2015)  ...            NaN
# 2778356                         Edit  ...            NaN
# 2778357          The Hangover (2015)  ...            NaN
# 2778358                         Edit  ...            NaN
#
# [2778359 rows x 9 columns]

# %% [markdown]
# ### **Step 1: Handling raw data**

# %%
# Merge screamo, punk rock, heavy metal to alt rock to simplify classification
# Too many genres can cause some trouble in classifying
data_csv['ranker_genre'] = np.where(
    (data_csv['ranker_genre'] == 'screamo')|
    (data_csv['ranker_genre'] == 'punk rock')|
    (data_csv['ranker_genre'] == 'heavy metal'), 
    'alt rock', 
    data_csv['ranker_genre']
)

# All label to lower case
data_csv['ranker_genre'] = np.where((data_csv['ranker_genre'] == 'Country'), 'country',  data_csv['ranker_genre'])
data_csv['ranker_genre'] = np.where((data_csv['ranker_genre'] == 'Hip Hop'), 'hip hop',  data_csv['ranker_genre'])

# For debugging
data_csv['ranker_genre'].value_counts()
# Out:
# country             838537
# alt rock            742989
# hip hop             632979
# rhythm and blues    331234
# pop                 232620
# Name: ranker_genre, dtype: int64

# %%
# Data is available as 1 lyric per row. Merge to 1 song per row
group = ['song', 'year', 'album', 'genre', 'artist', 'ranker_genre']
lyrics_by_song = data_csv.sort_values(group).groupby(group).lyric.apply(' '.join).apply(lambda x: x.lower()).reset_index(name='lyric')

# Remove non-alphanumeric characters
lyrics_by_song["lyric"] = lyrics_by_song['lyric'].str.replace(r'[^\w\s+]','')

# For debugging
lyrics_by_song
# Out:
#                                  song  ...                                              lyric
# 0                           Bad Girl   ...  theres a rumor youre the talk of the town ther...
# 1                  Cheese Tomato Man   ...  cheese tomato flan crazy little man quiche lor...
# 2                   Daydreamers Night  ...  shroud cloak veil smoke in camera masquerade i...
# 3                        Do It To Me   ...  theres a kid who just found that love is not a...
# 4             Hello Farewell Goodbye   ...  oh we kiss and we fight then we make up all ni...
# ...                               ...  ...                                                ...
# 62150                      www.memory  ...  i know your leavin i see the signs your gonna ...
# 62151                  xOn Our Kneesx  ...  i dont want it i dont want it i dont want it i...
# 62152                           ¡Olé!  ...  olexs 12 oleall xs 12 the bouncing souls no on...
# 62153                ¡Viva La Gloria!  ...  hey gloria are you standing close to the edge ...
# 62154  ¿Viva La Gloria? (Little Girl)  ...  little girl little girl why are you crying ins...
#
# [62155 rows x 7 columns]

# %%
# Clean unecessary column
group = ['song', 'ranker_genre', 'lyric']
lyrics_by_song = lyrics_by_song[group]

# For debugging
print(lyrics_by_song.shape)
lyrics_by_song
# Out:
# (62155, 3)
#                                  song  ...                                              lyric
# 0                           Bad Girl   ...  theres a rumor youre the talk of the town ther...
# 1                  Cheese Tomato Man   ...  cheese tomato flan crazy little man quiche lor...
# 2                   Daydreamers Night  ...  shroud cloak veil smoke in camera masquerade i...
# 3                        Do It To Me   ...  theres a kid who just found that love is not a...
# 4             Hello Farewell Goodbye   ...  oh we kiss and we fight then we make up all ni...
# ...                               ...  ...                                                ...
# 62150                      www.memory  ...  i know your leavin i see the signs your gonna ...
# 62151                  xOn Our Kneesx  ...  i dont want it i dont want it i dont want it i...
# 62152                           ¡Olé!  ...  olexs 12 oleall xs 12 the bouncing souls no on...
# 62153                ¡Viva La Gloria!  ...  hey gloria are you standing close to the edge ...
# 62154  ¿Viva La Gloria? (Little Girl)  ...  little girl little girl why are you crying ins...
#
# [62155 rows x 3 columns]

# %% [markdown]
# ### **Step 2: Featurizing**

# %%
# Constant
MIN_LYRIC_LEN = 400
TRAIN_FRACTION = 0.8
RANDOM_SEED = 150

# Only accept song with more than 400 characters
# Since shorter songs usually contain meaningless phrases
lyrics_by_song = lyrics_by_song[lyrics_by_song.lyric.str.len() > MIN_LYRIC_LEN]
lyrics_by_song = lyrics_by_song.reset_index(drop=True)

# Split all the lyric words
lyrics_by_song['words'] = lyrics_by_song['lyric'].str.split()

# Clean lyric words by lemantizing and stop words
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words('english')
stopwords_dict = Counter(stop_words)

def lemmatize_stop(lyric_words):
  # Lemantizing
  for i in range(len(lyric_words)):
    lyric_words[i] = lemmatizer.lemmatize(lyric_words[i])

  # Stop word
  lyric_words = [lemmatizer.lemmatize(word) for word in lyric_words if word not in stopwords_dict]  
  return lyric_words

#lyrics_by_song['words'].apply(lemmatize_stop) # Uncomment this line to use lemmatizing and stop words

# For debugging
lyrics_by_song
# Out:
#                                  song  ...                                              words
# 0                           Bad Girl   ...  [theres, a, rumor, youre, the, talk, of, the, ...
# 1                  Cheese Tomato Man   ...  [cheese, tomato, flan, crazy, little, man, qui...
# 2                   Daydreamers Night  ...  [shroud, cloak, veil, smoke, in, camera, masqu...
# 3                        Do It To Me   ...  [theres, a, kid, who, just, found, that, love,...
# 4             Hello Farewell Goodbye   ...  [oh, we, kiss, and, we, fight, then, we, make,...
# ...                               ...  ...                                                ...
# 59904                      www.memory  ...  [i, know, your, leavin, i, see, the, signs, yo...
# 59905                      www.memory  ...  [i, know, your, leavin, i, see, the, signs, yo...
# 59906                           ¡Olé!  ...  [olexs, 12, oleall, xs, 12, the, bouncing, sou...
# 59907                ¡Viva La Gloria!  ...  [hey, gloria, are, you, standing, close, to, t...
# 59908  ¿Viva La Gloria? (Little Girl)  ...  [little, girl, little, girl, why, are, you, cr...
#
# [59909 rows x 4 columns]

# %%
# Bigram featurizer
def bigram(lyric_words):
  return list(ngrams(lyric_words, 2))

lyrics_by_song['lyric_words'] = lyrics_by_song['words'].apply(bigram)
#lyrics_by_song['lyric_words'] = lyrics_by_song['words'] # Uncomment this line to use unigram instead

# For debugging
lyrics_by_song
# Out:
#                                  song  ...                                        lyric_words
# 0                           Bad Girl   ...  [(theres, a), (a, rumor), (rumor, youre), (you...
# 1                  Cheese Tomato Man   ...  [(cheese, tomato), (tomato, flan), (flan, craz...
# 2                   Daydreamers Night  ...  [(shroud, cloak), (cloak, veil), (veil, smoke)...
# 3                        Do It To Me   ...  [(theres, a), (a, kid), (kid, who), (who, just...
# 4             Hello Farewell Goodbye   ...  [(oh, we), (we, kiss), (kiss, and), (and, we),...
# ...                               ...  ...                                                ...
# 59904                      www.memory  ...  [(i, know), (know, your), (your, leavin), (lea...
# 59905                      www.memory  ...  [(i, know), (know, your), (your, leavin), (lea...
# 59906                           ¡Olé!  ...  [(olexs, 12), (12, oleall), (oleall, xs), (xs,...
# 59907                ¡Viva La Gloria!  ...  [(hey, gloria), (gloria, are), (are, you), (yo...
# 59908  ¿Viva La Gloria? (Little Girl)  ...  [(little, girl), (girl, little), (little, girl...
#
# [59909 rows x 5 columns]

# %%
from sklearn.utils import shuffle

# List of genres for classifying
genres = list(set(lyrics_by_song["ranker_genre"]))
print(genres)

# Train and test set
train_dataframe = pd.DataFrame()
test_dataframe = pd.DataFrame()

for genre in genres:
  # Split train - test by ratio of 8 - 2
  lyrics_by_song_qualified = lyrics_by_song[(lyrics_by_song.ranker_genre==genre)]
  train_set = lyrics_by_song_qualified.sample(frac = TRAIN_FRACTION, random_state = RANDOM_SEED)
  test_set = lyrics_by_song_qualified.drop(train_set.index)
  train_dataframe = train_dataframe.append(train_set)
  test_dataframe = test_dataframe.append(test_set)

# Shuffle and reset train - test index
train_dataframe = shuffle(train_dataframe).reset_index(drop=True)
test_dataframe = shuffle(test_dataframe).reset_index(drop=True)

# For debugging
print(train_dataframe.head())
print(train_dataframe.shape)
print(test_dataframe.head())
print(test_dataframe.shape)
# Out:
# ['hip hop', 'country', 'alt rock', 'rhythm and blues', 'pop']
#                        song  ...                                        lyric_words
# 0  Everything That You Want  ...  [(in, the), (the, beginning), (beginning, the)...
# 1          Power Of My Love  ...  [(oh, break), (break, it), (it, burn), (burn, ...
# 2             So Much Betta  ...  [(tired, of), (of, being), (being, number), (n...
# 3         I Want You So Bad  ...  [(when, the), (the, wind), (wind, blows), (blo...
# 4      It's Christmas Again  ...  [(while, everyones), (everyones, dreamin), (dr...
#
# [5 rows x 5 columns]
# (47926, 5)
#                     song  ...                                        lyric_words
# 0                  Maria  ...  [(she, moves), (moves, like), (like, she), (sh...
# 1  Angel from Montgomery  ...  [(i, am), (am, an), (an, old), (old, woman), (...
# 2             Good Times  ...  [(when, i), (i, ran), (ran, to), (to, the), (t...
# 3  Hawaiian Wedding Song  ...  [(this, is), (is, the), (the, moment), (moment...
# 4        Full Disclosure  ...  [(oh, i), (i, dont), (dont, want), (want, one)...
#
# [5 rows x 5 columns]
# (11983, 5)

# %%
train_dataframe
# Out:
#                                   song  ...                                        lyric_words
# 0             Everything That You Want  ...  [(in, the), (the, beginning), (beginning, the)...
# 1                     Power Of My Love  ...  [(oh, break), (break, it), (it, burn), (burn, ...
# 2                        So Much Betta  ...  [(tired, of), (of, being), (being, number), (n...
# 3                    I Want You So Bad  ...  [(when, the), (the, wind), (wind, blows), (blo...
# 4                 It's Christmas Again  ...  [(while, everyones), (everyones, dreamin), (dr...
# ...                                ...  ...                                                ...
# 47921  I Love a Man in a Uniform (dub)  ...  [(time, with), (with, my), (my, girl), (girl, ...
# 47922                  About the Money  ...  [(bustin, out), (out, the), (the, bando), (ban...
# 47923                      God Is Love  ...  [(oh, dont), (dont, go), (go, and), (and, talk...
# 47924                       Modern Man  ...  [(ive, got), (got, nothing), (nothing, to), (t...
# 47925                    I'll Be There  ...  [(you, and), (and, i), (i, must), (must, make)...
#
# [47926 rows x 5 columns]

# %%
# For debugging
train_dataframe[(train_dataframe["ranker_genre"] == "alt rock")]
# Out:
#                                   song  ...                                        lyric_words
# 3                    I Want You So Bad  ...  [(when, the), (the, wind), (wind, blows), (blo...
# 5                    Get off the Phone  ...  [(10, years), (years, old), (old, anything), (...
# 14                    Join Us For Pong  ...  [(its, the), (the, gay), (gay, nineties), (nin...
# 15                         I've Had It  ...  [(i, cant), (cant, go), (go, to), (to, work), ...
# 22                      Beat Surrender  ...  [(beat, surrender), (surrender, come), (come, ...
# ...                                ...  ...                                                ...
# 47911            Til Wrong Feels Right  ...  [(i, took), (took, a), (a, pounding), (poundin...
# 47916                     91 Freestyle  ...  [(alone, i), (i, feel), (feel, abused), (abuse...
# 47918              Tomorrow's Industry  ...  [(young, kids), (kids, in), (in, catholic), (c...
# 47921  I Love a Man in a Uniform (dub)  ...  [(time, with), (with, my), (my, girl), (girl, ...
# 47924                       Modern Man  ...  [(ive, got), (got, nothing), (nothing, to), (t...
#
# [13678 rows x 5 columns]

# %%
# Create a word vocabulary - words must be unique
word_vocab = []
for words in train_dataframe['lyric_words']:
  word_vocab.extend(words)
word_vocab = set(word_vocab)

# For debugging
word_vocab
# Out:
# {('chains', 'you'),
#  ('rockwilder', 'on'),
#  ('the', 'talks'),
#  ('out', 'skeezin'),
#  ('good', 'die'),
#  ('byebye', 'sweet'),
#  ('miss', 'er'),
#  ('formed', 'a'),
#  ('touch', 'você'),
#  ('makin', 'neither'),
#  ('bad', 'most'),
#  ('stifle', 'ya'),
#  ('stairs', 'any'),
#  ('it', 'tickle'),
#  ('knockin', 'other'),
#  ('machine', 'ah'),
#  ('reminiscing', 'of'),
#  ('deep', 'the'),
#  ('bring', 'machine'),
#  ('hoodoo', 'you'),
#  ('michelangelo', 'picasso'),
#  ('champ', 'cause'),
#  ('rendered', 'i'),
#  ('and', 'dudes'),
#  ('heart', 'beguiled'),
#  ('to', 'mommy'),
#  ('curious', 'shorty'),
#  ('colas', 'in'),
#  ('trip', 'on'),
#  ('mother', 'longing'),
#  ('coulda', 'stood'),
#  ('dick', 'calling'),
#  ('grow', 'yes'),
#  ('little', 'shops'),
#  ('whoaoh', 'its'),
#  ('chair', 'on'),
#  ('bone', 'shallow'),
#  ('food', 'hands'),
#  ('lead', 'grinnin'),
#  ('arranged', 'you'),
#  ('class', 'put'),
#  ('gabbanas', 'hey'),
#  ('i', 'ingest'),
#  ('remark', 'rings'),
#  ('lotta', 'ass'),
#  ('on', 'star'),
#  ('bake', 'she'),
#  ('flicks', 'give'),
#  ('ventures', 'these'),
#  ('there', 'ambitions'),
#  ('are', 'terrorstruck'),
#  ('its', 'perpendicular'),
#  ('climbs', 'of'),
#  ('stop', 'lyin'),
#  ('rosemarie', 'whats'),
#  ('micks', 'a'),
#  ('strap', 'with'),
#  ('had', 'restraining'),
#  ('the', 'blazin'),
#  ('rolling', 'king'),
#  ('agree', 'hangin'),
#  ('before', 'dark'),
#  ('the', 'tuck'),
#  ('unknown', 'kept'),
#  ('store', 'clerk'),
#  ('be', 'easier'),
#  ('ask', 'niggas'),
#  ('puts', 'my'),
#  ('em', 'share'),
#  ('hip', 'its'),
#  ('personal', 'hygiene'),
#  ('cadillac', 'limosine'),
#  ('italy', 'to'),
#  ('jusr', 'get'),
#  ('someone', 'faithful'),
#  ('rocky', 'creek'),
#  ('people', 'listened'),
#  ('maybe', 'one'),
#  ('angel', 'sock'),
#  ('glows', 'its'),
#  ('black', 'brothers'),
#  ('had', 'gained'),
#  ('world', 'nigga'),
#  ('villa', 'loft'),
#  ('day', 'trying'),
#  ('movin', 'scarface'),
#  ('crying', 'anymore'),
#  ('steps', 'i'),
#  ('thats', 'turned'),
#  ('pieces', 'scattered'),
#  ('bossolino', 'scammin'),
#  ('triflinass', 'women'),
#  ('game', 'ask'),
#  ('blindfold', 'gagged'),
#  ('dreams', 'joining'),
#  ('land', 'protect'),
#  ('niemans', 'so'),
#  ('route', 'selling'),
#  ('un', 'bebe'),
#  ('factors', 'high'),
#  ('drastic', 'bold'),
#  ('christmas', 'shining'),
#  ('your', 'barrier'),
#  ('is', 'snapple'),
#  ('alot', 'better'),
#  ('djs', 'in'),
#  ('stop', 'come'),
#  ('whistlin', 'wind'),
#  ('old', 'brogan'),
#  ('sitting', 'behind'),
#  ('unforgiven', 'for'),
#  ('with', 'tall'),
#  ('war', 'poverty'),
#  ('right', 'planet'),
#  ('shutting', 'you'),
#  ('fat', 'funky'),
#  ('got', 'fightin'),
#  ('whizzin', 'bad'),
#  ('stands', 'watch'),
#  ('this', 'ja'),
#  ('contemplated', 'on'),
#  ('busterass', 'niggas'),
#  ('desire', 'release'),
#  ('change', 'raekwon'),
#  ('all', 'expression'),
#  ('worthy', 'so'),
#  ('lungs', 'i'),
#  ('find', 'temptation'),
#  ('duckin', 'that'),
#  ('practice', 'baby'),
#  ('attempts', 'of'),
#  ('tables', 'at'),
#  ('than', 'letters'),
#  ('outro', 'method'),
#  ('to', 'release'),
#  ('drifts', 'along'),
#  ('workgame', 'give'),
#  ('absence', 'is'),
#  ('lily', 'it'),
#  ('expensive', 'perfume'),
#  ('dare', 'people'),
#  ('ballroom', 'were'),
#  ('alright', 'theres'),
#  ('forbid', 'fate'),
#  ('sinister', 'sleep'),
#  ('an', 'expansion'),
#  ('and', 'dollarless'),
#  ('eden', 'jog'),
#  ('nobodies', 'bodys'),
#  ('christ', 'every'),
#  ('germs', 'wrapped'),
#  ('car', 'women'),
#  ('blue', 'take'),
#  ('also', 'cribs'),
#  ('whiffle', 'strippin'),
#  ('thoughts', 'always'),
#  ('a', 'tightly'),
#  ('seem', 'half'),
#  ('mind', 'turnin'),
#  ('feature', 'they'),
#  ('margaritas', 'coconut'),
#  ('dog', 'competition'),
#  ('models', 'lookin'),
#  ('six', 'now'),
#  ('you', 'dolly'),
#  ('flows', 'no'),
#  ('then', 'know'),
#  ('the', 'outraged'),
#  ('no', 'shalom'),
#  ('barbecue', 'the'),
#  ('ending', 'even'),
#  ('us', 'somebody'),
#  ('my', 'starter'),
#  ('swallows', 'me'),
#  ('that', 'beat'),
#  ('see', 'ooh'),
#  ('jenny', 'dont'),
#  ('bust', 'style'),
#  ('reaping', 'a'),
#  ('tis', 'only'),
#  ('flagellants', 'spreadin'),
#  ('shorts', 'but'),
#  ('hits', 'pickpickin'),
#  ('journey', 'up'),
#  ('breezin', 'their'),
#  ('delirious', 'delirious'),
#  ('eels', 'para'),
#  ('ima', 'heat'),
#  ('people', 'diggin'),
#  ('wide', 'no'),
#  ('nephew', 'nephew'),
#  ('given', 'love'),
#  ('underway', 'for'),
#  ('elements', 'i'),
#  ('are', 'thin'),
#  ('went', 'insane'),
#  ('ànd', 'whoms'),
#  ('digit', 'anything'),
#  ('eazy', 'in'),
#  ('swored', 'to'),
#  ('and', 'twats'),
#  ('cant', 'scream'),
#  ('dress', 'you'),
#  ('perfect', 'allamerican'),
#  ('gate', 'closing'),
#  ('we', 'how'),
#  ('seat', 'youve'),
#  ('getting', 'sentimental'),
#  ('secret', 'though'),
#  ('fuck', 'neighbors'),
#  ('sip', 'why'),
#  ('be', 'plantin'),
#  ('the', '300'),
#  ('stinkin', 'enough'),
#  ('push', 'her'),
#  ('and', 'important'),
#  ('fire', 'swing'),
#  ('me', 'backstrokin'),
#  ('knew', 'honey'),
#  ('alumni', 'lookin'),
#  ('moon', 'would'),
#  ('still', 'smells'),
#  ('not', 'times'),
#  ('puttin', 'niggaz'),
#  ('and', 'diamonds'),
#  ('rage', 'kid'),
#  ('buzzed', 'with'),
#  ('insider', 'dealings'),
#  ('a', 'pendelum'),
#  ('honesty', 'that'),
#  ('wanders', 'alone'),
#  ('estranged', 'baby'),
#  ('is', 'searching'),
#  ('fine', 'though'),
#  ('tweezy', 'im'),
#  ('she', 'pournin'),
#  ('men', 'should'),
#  ('mammys', 'spot'),
#  ('freak', 'planet'),
#  ('landmark', 'praise'),
#  ('niggas', 'buy'),
#  ('johnnies', 'date'),
#  ('flossed', 'out'),
#  ('fars', 'away'),
#  ('want', 'without'),
#  ('like', 'mannie'),
#  ('nut', '3'),
#  ('your', 'shinny'),
#  ('weekends', 'ten'),
#  ('the', 'cheerleaders'),
#  ('tryna', 'battle'),
#  ('laptop', 'ah'),
#  ('clean', 'crazy'),
#  ('team', 'hot'),
#  ('window', 'tinted'),
#  ('that', 'pullman'),
#  ('rigs', 'a'),
#  ('roll', 'shoes'),
#  ('connection', 'and'),
#  ('was', 'simpler'),
#  ('handinhands', 'sunday'),
#  ('tower', 'let'),
#  ('not', 'taste'),
#  ('pleasin', 'honey'),
#  ('waterfalls', 'in'),
#  ('the', 'kingdoms'),
#  ('seeker', 'you'),
#  ('her', 'gynecologist'),
#  ('ghost', 'floating'),
#  ('thatll', 'crush'),
#  ('my', 'hours'),
#  ('girl', 'hook'),
#  ('dublins', 'and'),
#  ('poor', 'hawaiian'),
#  ('bay', 'lambo'),
#  ('benz', 'ghostwriter'),
#  ('where', 'talkin'),
#  ('a', 'talkshow'),
#  ('the', 'cowardice'),
#  ('street', 'got'),
#  ('bayou', 'they'),
#  ('longawaited', 'king'),
#  ('fakes', 'you'),
#  ('be', 'done'),
#  ('we', 'niggas'),
#  ('cup', 'nigga'),
#  ('fingers', 'snared'),
#  ('today', 'nobody'),
#  ('fifth', 'like'),
#  ('pumpll', 'put'),
#  ('like', 'quiet'),
#  ('hers', 'sweet'),
#  ('robin', 'bring'),
#  ('spit', 'faces'),
#  ('im', 'wrestlin'),
#  ('thought', 'living'),
#  ('only', 'kinda'),
#  ('gone', 'is'),
#  ('goin', 'smooth'),
#  ('out', 'fnf'),
#  ('tastefully', 'so'),
#  ('gangstawhat', 'tha'),
#  ('drawing', 'patterns'),
#  ('yo', 'mary'),
#  ('mimic', 'him'),
#  ('cripple', 'i'),
#  ('like', 'as'),
#  ('a', 'battles'),
#  ('was', 'nigga'),
#  ('been', 'retired'),
#  ('daddy', 'drank'),
#  ('fills', 'our'),
#  ('tricks', 'wanna'),
#  ('that', 'maximum'),
#  ('fortyfour', 'years'),
#  ('too', 'more'),
#  ('overwhelming', 'cant'),
#  ('could', 'someones'),
#  ('your', 'promisekeeper'),
#  ('another', 'pair'),
#  ('promised', 'darlin'),
#  ('lawyer', 'told'),
#  ('dancer', 'know'),
#  ('funny', 'darn'),
#  ('right', 'color'),
#  ('wouldnt', 'turn'),
#  ('drowse', 'the'),
#  ('fab', 'f'),
#  ('taysha', 'and'),
#  ('2', 'fine'),
#  ('books', 'illustrate'),
#  ('behind', 'door'),
#  ('eyed', 'she'),
#  ('insidious', 'design'),
#  ('use', 'cryin'),
#  ('slangin', 'dope'),
#  ('dog', 'running'),
#  ('die', 'redeeming'),
#  ('offering', '50'),
#  ('valley', 'daddys'),
#  ('burdon', 'and'),
#  ('green', 'can'),
#  ('slangin', 'ya'),
#  ('said', 'freedom'),
#  ('spins', 'too'),
#  ('snatched', 'out'),
#  ('its', '2004'),
#  ('walkin', 'well'),
#  ('playoff', 'thered'),
#  ('game', 'time'),
#  ('early', 'every'),
#  ('renegades', 'with'),
#  ('your', 'selective'),
#  ('or', 'fly'),
#  ('trucks', 'backfire'),
#  ('anymore', 'on'),
#  ('ha', 'everythings'),
#  ('you', 'meditator'),
#  ('bus', 'and'),
#  ('entry', 'wound'),
#  ('day', 'slipped'),
#  ('imma', 'expose'),
#  ('stage', 'as'),
#  ('foolish', 'will'),
#  ('sabrina', 'uh'),
#  ('loves', 'up'),
#  ('jack', 'headfirst'),
#  ('causing', 'ruckus'),
#  ('yo', 'collateral'),
#  ('aside', 'insidious'),
#  ('and', 'withdrawn'),
#  ('guarding', 'double'),
#  ('ma', 'best'),
#  ('thank', 'everybody'),
#  ('fall', 'cowards'),
#  ('a', 'awful'),
#  ('gurl', 'a'),
#  ('humble', 'give'),
#  ('fuck', 'right'),
#  ('rat', 'face'),
#  ('an', 'animal'),
#  ('baby', 'whatcha'),
#  ('juice', 'with'),
#  ('rockets', 'and'),
#  ('parrot', 'in'),
#  ('love', 'scuffed'),
#  ('challenges', 'and'),
#  ('boards', 'will'),
#  ('thing', 'watchin'),
#  ('the', 'meekest'),
#  ('brian', 'cox'),
#  ('calf', 'that'),
#  ('writer', 'even'),
#  ('joey', 'to'),
#  ('electric', 'slide'),
#  ('frankie', 'play'),
#  ('hear', 'fetti'),
#  ('kangol', 'i'),
#  ('and', 'primal'),
#  ('dass', 'dieser'),
#  ('haha', 'im'),
#  ('celebratin', 'somethin'),
#  ('hundred', 'bottles'),
#  ('not', 'somewhere'),
#  ('prego', 'call'),
#  ('change', 'touched'),
#  ('were', 'over'),
#  ('with', 'crimes'),
#  ('most', 'bigger'),
#  ('should', 'slow'),
#  ('apple', 'in'),
#  ('venome', 's'),
#  ('presents', 'nigga'),
#  ('to', 'scrath'),
#  ('holds', 'it'),
#  ('in', 'literal'),
#  ('internal', 'missileinternal'),
#  ('lit', 'strait'),
#  ('85', 'southbound'),
#  ('were', 'those'),
#  ('pose', 'guns'),
#  ('loudmouth', 'type'),
#  ('research', 'lies'),
#  ('we', 'killin'),
#  ('clouds', 'had'),
#  ('dreaming', 'tonight'),
#  ('a', 'register'),
#  ('babe', 'there'),
#  ('oh', 'london'),
#  ('expressed', 'herself'),
#  ('bullets', 'start'),
#  ('alert', 'first'),
#  ('occasional', 'kiss'),
#  ('they', 'anit'),
#  ('colombian', 'name'),
#  ('its', 'sweaty'),
#  ('of', 'stretch'),
#  ('skipped', 'past'),
#  ('naughty', 'just'),
#  ('not', 'flew'),
#  ('cheat', 'tomorrow'),
#  ('last', 'crew'),
#  ('wilful', 'days'),
#  ('him', 'honey'),
#  ('hoes', 'go'),
#  ('mice', 'do'),
#  ('lamp', 'who'),
#  ('return', 'ill'),
#  ('diamonds', 'took'),
#  ('siamese', '2s'),
#  ('ill', 'speaking'),
#  ('ohoh', 'whoawhoa'),
#  ('youre', 'game'),
#  ('inside', 'slums'),
#  ('persuade', 'everyone'),
#  ('beef', 'settle'),
#  ('fate', 'ran'),
#  ('video', 'darkskinned'),
#  ('gusta', 'ill'),
#  ('my', 'essays'),
#  ('at', 'chancellorsville'),
#  ('dro', 'to'),
#  ('rap', 'fiend'),
#  ('baby', 'whoop'),
#  ('recognize', 'in'),
#  ('months', 'at'),
#  ('min', 'seconds'),
#  ('benificent', 'i'),
#  ('breathtakin', 'lovemakin'),
#  ('theres', 'santa'),
#  ('predominantly', 'white'),
#  ('less', 'about'),
#  ('they', 'smelled'),
#  ('signed', 'dizzy'),
#  ('sa', 'if'),
#  ('kansas', 'to'),
#  ('sometimes', 'bound'),
#  ('reflection', 'captured'),
#  ('porch', 'im'),
#  ('out', 'dang'),
#  ('out', 'shaq'),
#  ('sick', 'munk'),
#  ('tonight', 'rise'),
#  ('holy', 'moses'),
#  ('another', 'headline'),
#  ('danga', 'and'),
#  ('executioner', 'of'),
#  ('rock', 'why'),
#  ('warm', 'september'),
#  ('tennessee', 'anywhere'),
#  ('not', 'warn'),
#  ('em', '10'),
#  ('ah', 'ba'),
#  ('pms', 'i'),
#  ('heart', 'cloudy'),
#  ('of', 'headspace'),
#  ('twisted', 'watch'),
#  ('the', 'patter'),
#  ('gon', 'last'),
#  ('uncle', 'gangsta'),
#  ('spots', 'we'),
#  ('kuzey', 'türk'),
#  ('tomb', 'stone'),
#  ('if', 'heartaches'),
#  ('luck', 'wind'),
#  ('their', 'joy'),
#  ('20', 'inta'),
#  ('knuckle', 'heads'),
#  ('like', 'cuts'),
#  ('claus', 'here'),
#  ('running', 'were'),
#  ('bein', 'some'),
#  ('verdict', 'we'),
#  ('this', 'lifes'),
#  ('punishments', 'that'),
#  ('poets', 'do'),
#  ('them', 'gussied'),
#  ('instrumental', 'now'),
#  ('runnin', 'his'),
#  ('flame', 'hell'),
#  ('narrow', 'that'),
#  ('drinkin', 'enough'),
#  ('their', 'brand'),
#  ('time', 'back'),
#  ('sleepwalking', 'effigies'),
#  ('plannin', 'yammin'),
#  ('we', 'bashes'),
#  ('cutting', 'yourself'),
#  ('shock', 'fish'),
#  ('body', 'leanin'),
#  ('futile', 'to'),
#  ('a', 'suitcase'),
#  ('box', 'took'),
#  ('chorus', 'jt'),
#  ('renowned', 'there'),
#  ('only', 'spit'),
#  ('today', 'stand'),
#  ('sayin', 'shes'),
#  ('wasnt', 'this'),
#  ('havoc', 'wanna'),
#  ('fingertips', 'on'),
#  ('indeed', 'that'),
#  ('damani', 'cause'),
#  ('eye', 'fightin'),
#  ('gonna', 'pitty'),
#  ('street', 'dude'),
#  ('testosterone', 'now'),
#  ('sheets', 'to'),
#  ('to', 'riffing'),
#  ('im', 'settling'),
#  ('someone', 'sucked'),
#  ('the', 'pants'),
#  ('trip', 'messing'),
#  ('list', 'my'),
#  ('train', 'have'),
#  ('dying', 'wont'),
#  ('dj', 'emena'),
#  ('faded', 'girl'),
#  ('escape', 'let'),
#  ('coal', 'look'),
#  ('your', 'band'),
#  ('kennel', 'ectoplasma'),
#  ('while', 'daz'),
#  ('nigger', 'and'),
#  ('oh', 'yeahie'),
#  ('monsinios', 'when'),
#  ('mathers', 'oh'),
#  ('burial', 'the'),
#  ('capital', 'where'),
#  ('lina', 'kurupt'),
#  ('rap', 'slate'),
#  ('a', 'fuckins'),
#  ('dilinquents', 'when'),
#  ('always', 'stormy'),
#  ('left', 'beside'),
#  ('world', 'acclaim'),
#  ('or', 'degrading'),
#  ('left', 'fifty'),
#  ('father', 'fucking'),
#  ('only', 'vulnerable'),
#  ('two', 'gals'),
#  ('being', 'thirsty'),
#  ('submergin', 'deeper'),
#  ('prince', 'jammy'),
#  ('breed', 'too'),
#  ('sense', 'occasional'),
#  ('collapsible', 'piece'),
#  ('their', 'task'),
#  ('ill', 'reload'),
#  ('wanna', 'clip'),
#  ('errerrerrerr', 'onomatopoeia'),
#  ('am', 'rollin'),
#  ('deep', 'shades'),
#  ('splinter', 'for'),
#  ('fathers', 'magic'),
#  ('amtrak', 'with'),
#  ('known', 'tracks'),
#  ('28s', 'you'),
#  ('soak', 'it'),
#  ('calls', 'boy'),
#  ('woo', 'until'),
#  ('wins', 'tired'),
#  ('into', 'judgments'),
#  ('giant', 'next'),
#  ('funkyass', 'shit'),
#  ('yo', 'spine'),
#  ('tommor', 'and'),
#  ('thuggers', 'i'),
#  ('élysées', 'aux'),
#  ('banging', 'ya'),
#  ('justice', 'call'),
#  ('or', 'for'),
#  ('bridge', 'blow'),
#  ('afraid', 'do'),
#  ('brincle', 'my'),
#  ('bedroom', 'break'),
#  ('outwardbound', 'made'),
#  ('bones', 'uneasy'),
#  ('dudes', 'will'),
#  ('got', 'enslaved'),
#  ('bucking', 'like'),
#  ('glass', 'duke'),
#  ('rollin', 'oh'),
#  ('dimming', 'down'),
#  ('cha', 'later'),
#  ('vanity', 'i'),
#  ('theyre', 'twistin'),
#  ('brothers', 'shit'),
#  ('jayz', 'check'),
#  ('this', 'grudge'),
#  ('baby', 'jiggle'),
#  ('ya', 'casa'),
#  ('designin', 'your'),
#  ('flame', 'man'),
#  ('fluss', 'and'),
#  ('and', 'bodyguards'),
#  ('fly', 'give'),
#  ('stones', 'can'),
#  ('she', 'eat'),
#  ('us', 'thinking'),
#  ('start', 'us'),
#  ('shatter', 'proof'),
#  ('slide', 'dont'),
#  ('many', 'lifetimes'),
#  ('tires', 'in'),
#  ('tried', 'long'),
#  ('nggas', 'want'),
#  ('ill', 'aways'),
#  ('to', 'clapclap'),
#  ('missed', 'think'),
#  ('little', 'victims'),
#  ('triumphs', 'once'),
#  ('lovesick', 'its'),
#  ('fittest', 'are'),
#  ('out', 'waits'),
#  ('resources', 'corporate'),
#  ('hand', 'resting'),
#  ('to', 'acapulco'),
#  ('hustle', 'rebellin'),
#  ('niggas', 'something'),
#  ('check', 'nike'),
#  ('long', 'expectant'),
#  ('toys', 'he'),
#  ('wicked', 'minded'),
#  ('terminate', 'the'),
#  ('gave', 'alyssa'),
#  ('pill', 'can'),
#  ('dead', 'because'),
#  ('ro', 'a'),
#  ('are', 'dreamy'),
#  ('got', 'bar'),
#  ('easily', 'think'),
#  ('police', 'nah'),
#  ('skills', 'will'),
#  ('windows', 'coming'),
#  ('box', 'will'),
#  ('youtube', 'goear'),
#  ('burning', 'sky'),
#  ('for', 'forcing'),
#  ('on', 'wheel'),
#  ('clown', 'you'),
#  ('true', 'doggz'),
#  ('still', 'gettin'),
#  ('get', 'creamed'),
#  ('crack', 'wood'),
#  ('how', 'proudly'),
#  ('the', 'scorchin'),
#  ('christ', 'who'),
#  ('mens', 'hearts'),
#  ('long', 'curly'),
#  ('into', 'leaving'),
#  ('bloomin', 'neath'),
#  ('oohooh', 'in'),
#  ('poet', 'while'),
#  ('mortality', 'when'),
#  ('girls', 'locked'),
#  ('shite', 'up'),
#  ('sale', 'but'),
#  ('naked', 'before'),
#  ('nigga', 'lloyd'),
#  ('you', 'drops'),
#  ('flatbush', 'and'),
#  ('you', 'moments'),
#  ('a', 'brighteyed'),
#  ('cum', 'in'),
#  ('world', 'walk'),
#  ('hab', 'keine'),
#  ('know', 'millz'),
#  ('is', 'dinner'),
#  ('surprising', 'twists'),
#  ('right', 'combination'),
#  ('natural', 'form'),
#  ('by', 'land'),
#  ('ribs', 'on'),
#  ('fear', 'rather'),
#  ('waiting', 'try'),
#  ('is', 'drunk'),
#  ('day', 'im'),
#  ('be', 'come'),
#  ('tumble', 'through'),
#  ('man', 'laughin'),
#  ('leader', 'descendent'),
#  ('funny', 'big'),
#  ('we', 'screamin'),
#  ('fortyeight', 'how'),
#  ('suffocate', 'amplify'),
#  ('signals', 'breaking'),
#  ('woe', 'eyes'),
#  ('one', 'cell'),
#  ('met', 'al'),
#  ('waving', 'i'),
#  ('pedel', 'to'),
#  ('convention', 'my'),
#  ('only', 'met'),
#  ('and', 'jenny'),
#  ('broadway', 'im'),
#  ('signatures', 'its'),
#  ('heart', 'tip'),
#  ('relief', 'have'),
#  ('victory', 'i'),
#  ('those', 'california'),
#  ('us', 'surrounded'),
#  ('my', 'cardio'),
#  ('goodfella', 'shit'),
#  ('neck', 'of'),
#  ('tomorrow', 'three'),
#  ('parole', 'on'),
#  ('stopping', 'youll'),
#  ('the', 'posttraumatic'),
#  ('meanest', 'cunt'),
#  ('our', 'invitations'),
#  ('mo', 'bun'),
#  ('whoo', 'she'),
#  ('mans', 'embrace'),
#  ('songs', 'forget'),
#  ('brightly', 'burned'),
#  ('indignant', 'icet'),
#  ('relapse', 'inference'),
#  ('in', 'tenderness'),
#  ('this', 'village'),
#  ('rappers', 'as'),
#  ('through', 'ya'),
#  ('bad', 'becomes'),
#  ('openin', 'em'),
#  ('you', 'lemme'),
#  ('prince', 'all'),
#  ('heat', 'break'),
#  ('hit', 'be'),
#  ('your', 'easmic'),
#  ('dog', 'push'),
#  ('grooving', 'god'),
#  ('toupee', 'now'),
#  ('list', 'going'),
#  ('need', 'protecting'),
#  ('you', 'wake'),
#  ('a', 'mambo'),
#  ('screaming', 'goodbye'),
#  ('cop', 'anything'),
#  ('dont', 'drugs'),
#  ('90s', 'in'),
#  ('ledge', 'thats'),
#  ('genieinabottle', 'im'),
#  ('guys', 'feel'),
#  ('ice', 'oh'),
#  ('valley', 'view'),
#  ('chicken', 'til'),
#  ('fo', 'door'),
#  ('ends', 'they'),
#  ('drugs', 'take'),
#  ('whispering', 'maple'),
#  ('10', 'after'),
#  ('is', 'gained'),
#  ('sway', 'carried'),
#  ('wanna', 'automatic'),
#  ('undergo', 'a'),
#  ('mariah', 'and'),
#  ('moving', 'persevere'),
#  ('tore', 'break'),
#  ('tock', 'tickety'),
#  ('the', 'can'),
#  ('youre', 'ok'),
#  ('for', 'school'),
#  ('tickin', 'but'),
#  ('ghost', 'well'),
#  ('and', 'spreads'),
#  ('enemy', 'get'),
#  ('is', 'free'),
#  ('and', 'jewels'),
#  ('quite', 'by'),
#  ('stranger', 'my'),
#  ('conquered', 'it'),
#  ('way', 'upon'),
#  ('props', 'whos'),
#  ('know', 'always'),
#  ('portray', 'leaves'),
#  ('my', 'innocence'),
#  ('sad', 'would'),
#  ('carpet', 'off'),
#  ('eloquent', 'thats'),
#  ('enough', 'federals'),
#  ('singin', 'an'),
#  ('stabledoor', 'sing'),
#  ('yall', 'around'),
#  ('doorway', 'minds'),
#  ('tor', 'ill'),
#  ('pitch', 'a'),
#  ('socalled', 'gank'),
#  ('def', 'squad'),
#  ('bleach', 'so'),
#  ('nothing', 'grows'),
#  ('wouldnt', 'bust'),
#  ('you', 'retreating'),
#  ('sally', 'five'),
#  ('care', 'invite'),
#  ('handlin', 'these'),
#  ('sipped', 'dacuries'),
#  ('napsack', 'filled'),
#  ('hearbeat', 'like'),
#  ('old', 'weve'),
#  ('boston', 'frisco'),
#  ('just', 'ashes'),
#  ('fucking', 'frightening'),
#  ('bust', 'your'),
#  ('better', 'started'),
#  ('frame', 'we'),
#  ('twice', 'but'),
#  ('dues', 'suddenly'),
#  ('on', 'breath'),
#  ('smarts', 'is'),
#  ('doing', 'dope'),
#  ('smackin', 'the'),
#  ('yeah', 'pushin'),
#  ('small', 'player'),
#  ('gab', 'ich'),
#  ('decisions', 'keep'),
#  ('that', 'fast'),
#  ('story', 'day'),
#  ('ooh', 'uhoh'),
#  ('dribbled', 'home'),
#  ('fantasy', 'pipe'),
#  ('yank', 'ya'),
#  ('angel', 'somewhere'),
#  ('lovely', 'and'),
#  ('no', 'chart'),
#  ('necessary', 'got'),
#  ('and', 'locomotion'),
#  ('im', 'green'),
#  ('and', 'charging'),
#  ('dj', 'will'),
#  ('pages', 'ahead'),
#  ('see', 'aeyed'),
#  ('were', 'backin'),
#  ('warm', 'comforter'),
#  ('style', 'trill'),
#  ('since', 'noah'),
#  ('club', '11'),
#  ('charts', 'were'),
#  ('again', 'fear'),
#  ('rich', 'with'),
#  ('gettin', 'deeper'),
#  ('anchors', 'up'),
#  ('rationality', 'again'),
#  ('cup', 'blunt'),
#  ('but', 'minutes'),
#  ('and', 'blink'),
#  ('kinda', 'popular'),
#  ('while', 'slow'),
#  ('needin', 'a'),
#  ('bull', 'so'),
#  ('drove', 'over'),
#  ('outs', 'the'),
#  ('floor', 'thumbin'),
#  ('a', 'waiving'),
#  ('desert', 'eagle'),
#  ('hours', 'seemed'),
#  ('was', 'natural'),
#  ('oww', 'i'),
#  ('lamborghini', 'half'),
#  ('bitter', 'complain'),
#  ('miserable', 'so'),
#  ('bad', 'ends'),
#  ('people', 'mourn'),
#  ('then', 'ride'),
#  ('a', 'profiting'),
#  ('heartaches', 'written'),
#  ('billy', 'bad'),
#  ('zero', 'context'),
#  ('carlo', 'and'),
#  ('minutes', 'dont'),
#  ('bulldog', 'to'),
#  ('fright', 'instead'),
#  ('minds', 'belief'),
#  ('broadcast', 'only'),
#  ('yard', 'but'),
#  ('of', 'bird'),
#  ('loving', 'wasnt'),
#  ('dales', 'junior'),
#  ('pinball', 'where'),
#  ('sausage', 'party'),
#  ('corrupted', 'the'),
#  ('big', 'pussy'),
#  ('fatties', 'made'),
#  ('a', 'horseback'),
#  ('angels', 'best'),
#  ('mascara', 'dripping'),
#  ('correctly', 'two'),
#  ('the', 'afterlife'),
#  ('crap', 'the'),
#  ('escaping', 'fear'),
#  ('hell', 'embracing'),
#  ('higher', 'tonight'),
#  ('ticking', 'cause'),
#  ('can', 'beg'),
#  ('spilled', 'enough'),
#  ('inventor', 'of'),
#  ('mic', 'she'),
#  ('pearlman', 'u'),
#  ('warm', 'summertime'),
#  ('haunting', 'elements'),
#  ('ronald', 'snoop'),
#  ('town', 'red'),
#  ('gimme', 'room'),
#  ('had', 'violent'),
#  ('shove', 'your'),
#  ('range', 'aint'),
#  ('cause', 'lady'),
#  ('town', 'wants'),
#  ('watch', 'scoobydoo'),
#  ('crown', 'brand'),
#  ('glove', 'box'),
#  ('troupe', 'a'),
#  ('bitch', 'kuniva'),
#  ('fuckin', 'style'),
#  ('climbin', 'bill'),
#  ('genetic', 'makeup'),
#  ('silk', 'blazers'),
#  ('back', 'great'),
#  ('be', 'holy'),
#  ('my', 'peddle'),
#  ('stood', '90'),
#  ('wound', 'there'),
#  ('womyn', 'well'),
#  ('thinking', 'throw'),
#  ('note', 'dies'),
#  ('all', 'vibrating'),
#  ('lives', 'why'),
#  ('my', 'flag'),
#  ('aint', 'sellin'),
#  ('whos', 'raving'),
#  ('blades', 'razor'),
#  ('shes', 'found'),
#  ('penetrate', 'that'),
#  ('him', 'black'),
#  ('fate', 'doesnt'),
#  ('lilgt', 'im'),
#  ('shells', 'couldnt'),
#  ('rocks', 'broke'),
#  ('see', 'peace'),
#  ('sin', 'an'),
#  ('out', 'street'),
#  ('savin', 'since'),
#  ('homicide', 'a'),
#  ('sees', 'too'),
#  ('playa', 'difference'),
#  ('sovallas', 'youll'),
#  ('muitas', 'pessoas'),
#  ('international', 'on'),
#  ('with', 'skimask'),
#  ('totem', 'pole'),
#  ('crossroads', 'and'),
#  ('cedar', 'my'),
#  ('we', 'outside'),
#  ('rockers', 'realise'),
#  ('really', 'try'),
#  ('money', 'beer'),
#  ('countries', 'ya'),
#  ('remember', 'honey'),
#  ('shorty', 'friend'),
#  ('and', 'coppertone'),
#  ('collapse', 'give'),
#  ...}

# %%
genre_data = dict()
for genre in genres:
  words = []
  train_dataframe.loc[train_dataframe['ranker_genre'] == genre, 'lyric_words'].apply(words.extend)
  genre_data[genre] = {
      'word_occurence': Counter(words), # count all the word occurence in the genre
      'count': len(words),
      'prob': train_dataframe['ranker_genre'].value_counts()[genre] / train_dataframe.shape[0]
  }

# For debugging
genre_data
# Out:
# {'alt rock': {'count': 3023831,
#   'prob': 0.28539832241372115,
#   'word_occurence': Counter({('when', 'the'): 1274,
#            ('the', 'wind'): 405,
#            ('wind', 'blows'): 66,
#            ('blows', 'through'): 6,
#            ('through', 'your'): 305,
#            ('your', 'hair'): 86,
#            ('hair', 'i'): 37,
#            ('i', 'want'): 2554,
#            ('want', 'you'): 694,
#            ('you', 'so'): 578,
#            ('so', 'bad'): 240,
#            ('bad', 'want'): 8,
#            ('bad', 'i'): 65,
#            ('i', 'see'): 1704,
#            ('see', 'your'): 352,
#            ('your', 'smile'): 67,
#            ('smile', 'boy'): 2,
#            ('boy', 'everywhere'): 2,
#            ('everywhere', 'i'): 69,
#            ('i', 'never'): 1415,
#            ('never', 'thought'): 270,
#            ('thought', 'this'): 34,
#            ('this', 'could'): 139,
#            ('could', 'happen'): 21,
#            ('happen', 'to'): 80,
#            ('to', 'me'): 2797,
#            ('me', 'if'): 260,
#            ('if', 'ive'): 23,
#            ('ive', 'fallen'): 36,
#            ('fallen', 'over'): 10,
#            ('over', 'you'): 173,
#            ('you', 'would'): 356,
#            ('would', 'it'): 74,
#            ('it', 'be'): 278,
#            ('be', 'so'): 328,
#            ('bad', 'would'): 2,
#            ('bad', 'every'): 2,
#            ('every', 'nights'): 4,
#            ('nights', 'an'): 2,
#            ('an', 'eternity'): 8,
#            ('eternity', 'i'): 5,
#            ('me', 'i'): 1998,
#            ('bad', 'bad'): 188,
#            ('bad', 'when'): 13,
#            ('bad', 'oh'): 5,
#            ('oh', 'i'): 505,
#            ('i', 'wonder'): 236,
#            ('wonder', 'if'): 75,
#            ('if', 'youre'): 442,
#            ('youre', 'aware'): 2,
#            ('aware', 'i'): 6,
#            ('if', 'you'): 2856,
#            ('you', 'care'): 93,
#            ('care', 'i'): 127,
#            ('this', 'would'): 61,
#            ('would', 'happen'): 16,
#            ('10', 'years'): 9,
#            ('years', 'old'): 49,
#            ('old', 'anything'): 2,
#            ('anything', 'goes'): 14,
#            ('goes', 'all'): 10,
#            ('all', 'you'): 671,
#            ('you', 'ever'): 497,
#            ('ever', 'knew'): 30,
#            ('knew', 'was'): 16,
#            ('was', 'a'): 1019,
#            ('a', 'bullshit'): 4,
#            ('bullshit', 'phone'): 2,
#            ('phone', 'now'): 5,
#            ('now', 'youre'): 488,
#            ('youre', 'on'): 200,
#            ('on', 'the'): 5929,
#            ('the', 'bells'): 51,
#            ('bells', 'yacking'): 2,
#            ('yacking', 'in'): 2,
#            ('in', 'the'): 10989,
#            ('the', 'booths'): 2,
#            ('booths', 'but'): 2,
#            ('but', 'where'): 29,
#            ('where', 'you'): 547,
#            ('you', 'supposed'): 3,
#            ('supposed', 'to'): 271,
#            ('to', 'go'): 1290,
#            ('go', 'well'): 39,
#            ('well', 'i'): 772,
#            ('i', 'just'): 1653,
#            ('just', 'dont'): 348,
#            ('dont', 'know'): 2241,
#            ('know', 'so'): 63,
#            ('so', 'get'): 113,
#            ('get', 'off'): 101,
#            ('off', 'the'): 537,
#            ('the', 'phone'): 259,
#            ('phone', 'theres'): 8,
#            ('theres', 'nobody'): 64,
#            ('nobody', 'home'): 34,
#            ('home', 'so'): 61,
#            ('phone', 'cause'): 12,
#            ('cause', 'i'): 1175,
#            ('i', 'dont'): 5975,
#            ('dont', 'want'): 1195,
#            ('you', 'cause'): 166,
#            ('you', 'whats'): 39,
#            ('whats', 'that'): 70,
#            ('that', 'ringing'): 2,
#            ('ringing', 'sound'): 3,
#            ('sound', 'everythings'): 2,
#            ('everythings', 'going'): 8,
#            ('going', 'round'): 38,
#            ('round', 'and'): 122,
#            ('and', 'round'): 99,
#            ('round', 'calling'): 4,
#            ('calling', 'everybody'): 2,
#            ('everybody', 'and'): 10,
#            ('and', 'their'): 89,
#            ('their', 'mother'): 10,
#            ('mother', 'too'): 5,
#            ('too', 'but'): 42,
#            ('but', 'dont'): 208,
#            ('dont', 'call'): 126,
#            ('call', 'me'): 681,
#            ('me', 'cause'): 298,
#            ('just', 'left'): 22,
#            ('left', 'you'): 92,
#            ('you', 'you'): 971,
#            ('you', 'hung'): 13,
#            ('hung', 'up'): 29,
#            ('up', 'on'): 428,
#            ('on', 'love'): 7,
#            ('love', 'when'): 73,
#            ('when', 'i'): 2217,
#            ('i', 'called'): 40,
#            ('called', 'that'): 2,
#            ('that', 'night'): 79,
#            ('night', 'you'): 101,
#            ('on', 'bells'): 2,
#            ('bells', 'at'): 2,
#            ('at', 'the'): 2181,
#            ('the', 'ring'): 76,
#            ('ring', 'side'): 2,
#            ('side', 'fights'): 2,
#            ('fights', 'you'): 3,
#            ('on', 'your'): 1530,
#            ('your', 'heart'): 832,
#            ('heart', 'you'): 92,
#            ('the', 'world'): 2782,
#            ('world', 'now'): 28,
#            ('now', 'you'): 617,
#            ('hung', 'yourself'): 2,
#            ('yourself', 'on'): 26,
#            ('the', 'telephone'): 72,
#            ('telephone', 'pole'): 2,
#            ('pole', 'so'): 2,
#            ('you', 'i'): 1983,
#            ('dont', 'care'): 891,
#            ('care', 'what'): 122,
#            ('what', 'you'): 2723,
#            ('you', 'wear'): 58,
#            ('wear', 'you'): 15,
#            ('you', 'aint'): 308,
#            ('aint', 'gonna'): 165,
#            ('gonna', 'go'): 217,
#            ('go', 'no'): 66,
#            ('no', 'where'): 38,
#            ('where', 'get'): 2,
#            ('its', 'the'): 914,
#            ('the', 'gay'): 2,
#            ('gay', 'nineties'): 1,
#            ('nineties', 'and'): 1,
#            ('and', 'you'): 1993,
#            ('you', 'cant'): 1936,
#            ('cant', 'watch'): 3,
#            ('watch', 'nothin'): 1,
#            ('nothin', 'good'): 7,
#            ('good', 'mindless'): 1,
#            ('mindless', 'pinko'): 1,
#            ('pinko', 'garbage'): 1,
#            ('garbage', 'is'): 1,
#            ('is', 'all'): 623,
#            ('all', 'they'): 73,
#            ('they', 'make'): 90,
#            ('make', 'in'): 2,
#            ('in', 'hollywood'): 16,
#            ('hollywood', 'kung'): 1,
#            ('kung', 'fu'): 34,
#            ('fu', 'theatre'): 1,
#            ('theatre', 'now'): 1,
#            ('now', 'theres'): 134,
#            ('theres', 'a'): 1089,
#            ('a', 'show'): 82,
#            ('show', 'with'): 9,
#            ('with', 'class'): 2,
#            ('class', 'id'): 1,
#            ('id', 'like'): 195,
#            ('like', 'to'): 653,
#            ('to', 'find'): 977,
#            ('find', 'the'): 399,
#            ('the', 'guy'): 39,
#            ('guy', 'who'): 30,
#            ('who', 'cancelled'): 1,
#            ('cancelled', 'it'): 1,
#            ('it', 'and'): 412,
#            ('and', 'karate'): 1,
#            ('karate', 'chop'): 3,
#            ('chop', 'his'): 1,
#            ('his', 'ass'): 10,
#            ('ass', 'so'): 9,
#            ('so', 'after'): 4,
#            ('after', 'alf'): 1,
#            ('alf', 'is'): 1,
#            ('is', 'done'): 132,
#            ('done', 'there'): 3,
#            ('there', 'aint'): 205,
#            ('aint', 'nothin'): 48,
#            ('good', 'on'): 18,
#            ('on', 'all'): 98,
#            ('all', 'my'): 826,
#            ('my', 'rowdy'): 1,
#            ('rowdy', 'friends'): 1,
#            ('friends', 'come'): 11,
#            ('come', 'over'): 56,
#            ('over', 'cause'): 10,
#            ('i', 'have'): 1723,
#            ('have', 'pong'): 1,
#            ('pong', 'join'): 1,
#            ('join', 'us'): 43,
#            ('us', 'join'): 7,
#            ('us', 'for'): 36,
#            ('for', 'pong'): 3,
#            ('pong', 'i'): 1,
#            ('i', 'got'): 2276,
#            ('got', 'the'): 918,
#            ('the', 'foxes'): 6,
#            ('foxes', 'i'): 1,
#            ('got', 'that'): 73,
#            ('that', 'clout'): 1,
#            ('clout', 'i'): 1,
#            ('got', 'my'): 310,
#            ('my', 'unit'): 1,
#            ('unit', 'on'): 1,
#            ('the', 'day'): 851,
#            ('day', 'they'): 34,
#            ('they', 'came'): 53,
#            ('came', 'out'): 31,
#            ('out', 'you'): 187,
#            ('you', 'bring'): 84,
#            ('bring', 'the'): 112,
#            ('the', 'snack'): 1,
#            ('snack', 'treats'): 1,
#            ('treats', 'you'): 5,
#            ('the', 'booze'): 15,
#            ('booze', 'i'): 2,
#            ('i', 'aint'): 606,
#            ('aint', 'bringin'): 1,
#            ('bringin', 'nothin'): 1,
#            ('nothin', 'does'): 1,
#            ('does', 'that'): 39,
#            ('that', 'box'): 3,
#            ('box', 'belong'): 1,
#            ('belong', 'to'): 76,
#            ('to', 'you'): 2078,
#            ('you', 'pass'): 33,
#            ('pass', 'the'): 84,
#            ('the', 'dutchies'): 1,
#            ('dutchies', 'on'): 1,
#            ('on', 'my'): 2015,
#            ('my', 'all'): 42,
#            ('all', 'time'): 51,
#            ('time', 'favorite'): 3,
#            ('favorite', 'song'): 26,
#            ('song', 'but'): 22,
#            ('but', 'turn'): 8,
#            ('turn', 'it'): 206,
#            ('it', 'down'): 452,
#            ('down', 'you'): 250,
#            ('you', 'moron'): 1,
#            ('moron', 'cause'): 1,
#            ('cause', 'were'): 117,
#            ('were', 'tryin'): 3,
#            ('tryin', 'to'): 105,
#            ('to', 'play'): 314,
#            ('play', 'pong'): 1,
#            ('pong', 'dont'): 1,
#            ('dont', 'be'): 377,
#            ('be', 'fooled'): 16,
#            ('fooled', 'by'): 17,
#            ('by', 'world'): 1,
#            ('world', 'peace'): 11,
#            ('peace', 'or'): 5,
#            ('or', 'an'): 18,
#            ('an', 'economy'): 1,
#            ('economy', 'thats'): 1,
#            ('thats', 'stable'): 1,
#            ('stable', 'the'): 1,
#            ('the', 'cias'): 1,
#            ('cias', 'just'): 1,
#            ('just', 'got'): 94,
#            ('got', 'more'): 23,
#            ('more', 'time'): 225,
#            ('time', 'to'): 1442,
#            ('to', 'watch'): 253,
#            ('watch', 'you'): 272,
#            ('you', 'through'): 120,
#            ('your', 'cable'): 1,
#            ('cable', 'they'): 1,
#            ('they', 'would'): 77,
#            ('would', 'control'): 2,
#            ('control', 'you'): 51,
#            ('you', 'and'): 1646,
#            ('and', 'take'): 356,
#            ('take', 'away'): 268,
#            ('away', 'your'): 85,
#            ('your', 'brain'): 98,
#            ('brain', 'you'): 14,
#            ('you', 'can'): 2778,
#            ('can', 'defeat'): 2,
#            ('defeat', 'them'): 3,
#            ('them', 'if'): 17,
#            ('you', 'switch'): 2,
#            ('switch', 'your'): 3,
#            ('your', 'box'): 2,
#            ('box', 'over'): 1,
#            ('over', 'to'): 51,
#            ('to', 'game'): 2,
#            ('game', 'do'): 1,
#            ('do', 'whats'): 36,
#            ('whats', 'right'): 86,
#            ('right', 'to'): 253,
#            ('you', 'not'): 56,
#            ('not', 'what'): 242,
#            ('what', 'they'): 497,
#            ('they', 'tell'): 72,
#            ('tell', 'you'): 905,
#            ('you', 'to'): 1273,
#            ('can', 'fight'): 20,
#            ('fight', 'we'): 27,
#            ('we', 'meet'): 33,
#            ('meet', 'tonight'): 6,
#            ('tonight', 'so'): 35,
#            ('so', 'join'): 5,
#            ('pong', 'its'): 1,
#            ('its', 'up'): 79,
#            ('up', 'to'): 703,
#            ('to', 'improve'): 11,
#            ('improve', 'your'): 4,
#            ('your', 'hand'): 305,
#            ('hand', 'eyecoordination'): 1,
#            ('eyecoordination', 'or'): 1,
#            ('or', 'become'): 2,
#            ('become', 'a'): 110,
#            ('a', 'mindless'): 12,
#            ('mindless', 'servant'): 1,
#            ('servant', 'unwitting'): 1,
#            ('unwitting', 'puppet'): 1,
#            ('puppet', 'of'): 1,
#            ('of', 'the'): 5750,
#            ('the', 'nation'): 59,
#            ('nation', 'they'): 1,
#            ('they', 'know'): 192,
#            ('know', 'your'): 208,
#            ('your', 'address'): 8,
#            ('address', 'they'): 1,
#            ('they', 'send'): 20,
#            ('send', 'you'): 50,
#            ('you', 'bills'): 1,
#            ('bills', 'they'): 1,
#            ('they', 'decide'): 5,
#            ('decide', 'if'): 8,
#            ('you', 'watch'): 34,
#            ('watch', 'tyson'): 1,
#            ('tyson', 'dont'): 1,
#            ('dont', 'that'): 2,
#            ('that', 'give'): 13,
#            ('give', 'you'): 543,
#            ('you', 'the'): 553,
#            ('the', 'chills'): 5,
#            ('chills', 'shake'): 1,
#            ('shake', 'off'): 13,
#            ('off', 'your'): 224,
#            ('your', 'shackles'): 1,
#            ('shackles', 'son'): 1,
#            ('son', 'weve'): 2,
#            ('weve', 'only'): 12,
#            ('only', 'just'): 69,
#            ('just', 'begun'): 91,
#            ('begun', 'theres'): 3,
#            ('theres', 'just'): 78,
#            ('just', 'two'): 48,
#            ('two', 'speeds'): 1,
#            ('speeds', 'its'): 1,
#            ('its', 'what'): 130,
#            ('you', 'need'): 651,
#            ('need', 'so'): 17,
#            ('i', 'cant'): 4429,
#            ('cant', 'go'): 193,
#            ('go', 'to'): 595,
#            ('to', 'work'): 149,
#            ('work', 'the'): 32,
#            ('the', 'boss'): 69,
#            ('boss', 'is'): 2,
#            ('is', 'a'): 1636,
#            ('a', 'jerk'): 45,
#            ('jerk', 'i'): 6,
#            ('aint', 'got'): 365,
#            ('got', 'time'): 99,
#            ('time', 'for'): 449,
#            ('for', 'this'): 382,
#            ('this', 'school'): 1,
#            ('school', 'the'): 1,
#            ('the', 'fuckers'): 2,
#            ('fuckers', 'are'): 3,
#            ('are', 'fools'): 1,
#            ('fools', 'im'): 1,
#            ('im', 'going'): 538,
#            ('going', 'to'): 582,
#            ('to', 'explode'): 63,
#            ('explode', 'ive'): 3,
#            ('ive', 'had'): 235,
#            ('had', 'it'): 220,
#            ('it', 'i'): 649,
#            ('i', 'lie'): 99,
#            ('lie', 'around'): 1,
#            ('around', 'with'): 131,
#            ('with', 'the'): 2074,
#            ('the', 'tv'): 90,
#            ('tv', 'on'): 8,
#            ('on', 'i'): 239,
#            ('dont', 'do'): 118,
#            ('do', 'nothin'): 6,
#            ('nothin', 'i'): 11,
#            ('just', 'hang'): 8,
#            ('hang', 'around'): 53,
#            ('around', 'waitin'): 1,
#            ('waitin', 'for'): 24,
#            ('for', 'your'): 642,
#            ('your', 'call'): 20,
#            ('call', 'but'): 13,
#            ('but', 'i'): 2802,
#            ('know', 'where'): 367,
#            ('where', 'to'): 138,
#            ('to', 'fall'): 314,
#            ('fall', 'haha'): 1,
#            ('haha', 'im'): 1,
#            ('it', 'its'): 261,
#            ('its', 'no'): 137,
#            ('no', 'use'): 114,
#            ('use', 'i'): 10,
#            ('cant', 'take'): 441,
#            ('take', 'no'): 71,
#            ('no', 'more'): 1116,
#            ('more', 'abuse'): 1,
#            ('abuse', 'im'): 3,
#            ('im', 'tired'): 188,
#            ('tired', 'of'): 412,
#            ('of', 'fuckin'): 5,
#            ('fuckin', 'lines'): 1,
#            ('lines', 'im'): 7,
#            ('im', 'losing'): 142,
#            ('losing', 'my'): 44,
#            ('my', 'mind'): 1270,
#            ('mind', 'im'): 64,
#            ('it', 'killin'): 1,
#            ('killin', 'all'): 1,
#            ('all', 'your'): 662,
#            ('your', 'dreams'): 205,
#            ('dreams', 'really'): 2,
#            ('really', 'who'): 3,
#            ('who', 'remembers'): 3,
#            ('remembers', 'i'): 1,
#            ('i', 'play'): 87,
#            ('play', 'guitar'): 5,
#            ('guitar', 'for'): 2,
#            ('for', 'my'): 428,
#            ('my', 'car'): 91,
#            ('car', 'haha'): 1,
#            ('haha', 'and'): 1,
#            ('and', 'i'): 6154,
#            ('i', 'wont'): 1764,
#            ('wont', 'get'): 135,
#            ('get', 'very'): 3,
#            ('very', 'far'): 26,
#            ('far', 'im'): 13,
#            ('beat', 'surrender'): 51,
#            ('surrender', 'come'): 39,
#            ('come', 'on'): 1327,
#            ('on', 'boy'): 49,
#            ('boy', 'come'): 51,
#            ('on', 'girl'): 67,
#            ('girl', 'succumb'): 48,
#            ('succumb', 'to'): 55,
#            ('to', 'the'): 5383,
#            ('the', 'beat'): 225,
#            ('surrender', 'all'): 11,
#            ('all', 'the'): 4150,
#            ('the', 'things'): 962,
#            ('things', 'that'): 478,
#            ('that', 'i'): 3114,
#            ('i', 'care'): 117,
#            ('care', 'about'): 170,
#            ('about', 'are'): 11,
#            ('are', 'packed'): 4,
#            ('packed', 'into'): 4,
#            ('into', 'one'): 24,
#            ('one', 'punch'): 5,
#            ('punch', 'all'): 3,
#            ('that', 'im'): 691,
#            ('im', 'not'): 2545,
#            ('not', 'sure'): 108,
#            ('sure', 'about'): 10,
#            ('are', 'sorted'): 3,
#            ('sorted', 'out'): 5,
#            ('out', 'at'): 68,
#            ('at', 'once'): 43,
#            ('once', 'and'): 37,
#            ('and', 'as'): 190,
#            ('as', 'it'): 278,
#            ('it', 'was'): 1428,
#            ('was', 'in'): 119,
#            ('the', 'beginning'): 84,
#            ('beginning', 'so'): 5,
#            ('so', 'shall'): 13,
#            ('shall', 'it'): 6,
#            ('be', 'in'): 145,
#            ('the', 'end'): 1842,
#            ('end', 'that'): 17,
#            ('that', 'bullshit'): 7,
#            ('bullshit', 'is'): 3,
#            ('is', 'bullshit'): 14,
#            ('bullshit', 'it'): 3,
#            ('it', 'just'): 390,
#            ('just', 'goes'): 24,
#            ('goes', 'by'): 65,
#            ('by', 'different'): 4,
#            ('different', 'names'): 12,
#            ('names', 'come'): 3,
#            ('i', 'shout'): 12,
#            ('shout', 'about'): 21,
#            ('about', 'but'): 9,
#            ('but', 'never'): 131,
#            ('never', 'act'): 4,
#            ('act', 'upon'): 3,
#            ('upon', 'all'): 3,
#            ('the', 'courage'): 21,
#            ('courage', 'and'): 11,
#            ('and', 'the'): 3401,
#            ('the', 'dreams'): 81,
#            ('dreams', 'i'): 67,
#            ('have', 'but'): 11,
#            ('but', 'seem'): 3,
#            ('seem', 'to'): 481,
#            ('to', 'wait'): 72,
#            ('wait', 'so'): 28,
#            ('so', 'long'): 615,
#            ('long', 'my'): 35,
#            ('my', 'doubt'): 9,
#            ('doubt', 'is'): 8,
#            ('is', 'cast'): 11,
#            ('cast', 'aside'): 27,
#            ('aside', 'watch'): 6,
#            ('watch', 'phonies'): 6,
#            ('phonies', 'run'): 6,
#            ('run', 'to'): 201,
#            ('to', 'hide'): 394,
#            ('hide', 'the'): 62,
#            ('the', 'dignified'): 6,
#            ('dignified', 'dont'): 6,
#            ('dont', 'even'): 251,
#            ('even', 'enter'): 6,
#            ('enter', 'in'): 7,
#            ('the', 'game'): 206,
#            ('game', 'come'): 6,
#            ('surrender', 'and'): 6,
#            ('and', 'if'): 927,
#            ('you', 'feel'): 909,
#            ('feel', 'theres'): 11,
#            ('theres', 'no'): 1517,
#            ('no', 'passion'): 8,
#            ('passion', 'no'): 5,
#            ('no', 'quality'): 3,
#            ('quality', 'sensation'): 3,
#            ('sensation', 'seize'): 3,
#            ('seize', 'the'): 33,
#            ('the', 'young'): 121,
#            ('young', 'determination'): 3,
#            ('determination', 'show'): 3,
#            ('show', 'the'): 107,
#            ('the', 'fakers'): 5,
#            ('fakers', 'you'): 3,
#            ('aint', 'foolin'): 3,
#            ('foolin', 'youll'): 3,
#            ('youll', 'see'): 197,
#            ('see', 'me'): 436,
#            ('me', 'come'): 152,
#            ('come', 'runnin'): 3,
#            ('runnin', 'to'): 3,
#            ('the', 'sound'): 400,
#            ('sound', 'of'): 274,
#            ('of', 'your'): 1394,
#            ('your', 'strummin'): 3,
#            ('strummin', 'fill'): 3,
#            ('fill', 'my'): 83,
#            ('my', 'heart'): 2096,
#            ('heart', 'with'): 43,
#            ('with', 'joy'): 9,
#            ('joy', 'and'): 16,
#            ('and', 'gladness'): 3,
#            ('gladness', 'ive'): 3,
#            ('ive', 'lived'): 42,
#            ('lived', 'too'): 7,
#            ('too', 'long'): 413,
#            ('long', 'in'): 29,
#            ('the', 'shadows'): 212,
#            ('shadows', 'of'): 41,
#            ('of', 'sadness'): 17,
#            ('sadness', 'my'): 5,
#            ('no', 'gods'): 15,
#            ('gods', 'no'): 13,
#            ('no', 'kings'): 12,
#            ('kings', 'only'): 11,
#            ('only', 'man'): 13,
#            ('man', 'they'): 31,
#            ('they', 'are'): 233,
#            ('are', 'not'): 342,
#            ('not', 'one'): 97,
#            ('one', 'of'): 433,
#            ('of', 'us'): 555,
#            ('us', 'they'): 41,
#            ('us', 'disconnected'): 1,
#            ('disconnected', 'and'): 5,
#            ('and', 'unwanted'): 1,
#            ('unwanted', 'distressed'): 1,
#            ('distressed', 'and'): 1,
#            ('and', 'cut'): 35,
#            ('cut', 'off'): 49,
#            ('off', 'hope'): 1,
#            ('hope', 'and'): 70,
#            ('and', 'despair'): 12,
#            ('despair', 'silencing'): 1,
#            ('silencing', 'the'): 1,
#            ('world', 'no'): 36,
#            ('man', 'no'): 34,
#            ('us', 'the'): 95,
#            ('the', 'future'): 378,
#            ('future', 'is'): 55,
#            ('is', 'black'): 39,
#            ('black', 'and'): 255,
#            ('and', 'gray'): 8,
#            ('gray', 'there'): 1,
#            ('there', 'is'): 939,
#            ('is', 'no'): 535,
#            ('no', 'tomorrow'): 59,
#            ('tomorrow', 'torn'): 1,
#            ('torn', 'apart'): 64,
#            ('apart', 'by'): 4,
#            ('by', 'weakness'): 1,
#            ('weakness', 'a'): 2,
#            ('a', 'cancer'): 22,
#            ('cancer', 'on'): 1,
#            ('the', 'earth'): 334,
#            ('earth', 'no'): 5,
#            ('man', 'the'): 39,
#            ('the', 'spirit'): 90,
#            ('spirit', 'lies'): 1,
#            ('lies', 'contaminated'): 1,
#            ('contaminated', 'the'): 1,
#            ('the', 'fall'): 122,
#            ('fall', 'of'): 22,
#            ('of', 'seduction'): 1,
#            ('seduction', 'transformation'): 1,
#            ('transformation', 'of'): 1,
#            ('of', 'yourself'): 32,
#            ('yourself', 'dark'): 1,
#            ('dark', 'clouds'): 9,
#            ('clouds', 'in'): 13,
#            ('in', 'your'): 2366,
#            ('i', 'feel'): 1869,
#            ('feel', 'like'): 657,
#            ('like', 'a'): 2885,
#            ('a', 'wog'): 10,
#            ('wog', 'people'): 2,
#            ('people', 'giving'): 4,
#            ('giving', 'me'): 49,
#            ('me', 'the'): 769,
#            ('the', 'eyes'): 195,
#            ('eyes', 'but'): 58,
#            ('i', 'was'): 2745,
#            ('was', 'born'): 238,
#            ('born', 'here'): 5,
#            ('here', 'just'): 37,
#            ('just', 'like'): 1058,
#            ('like', 'you'): 895,
#            ('wog', 'got'): 2,
#            ('got', 'all'): 94,
#            ('the', 'dirt'): 99,
#            ('dirt', 'shitty'): 2,
#            ('shitty', 'jobs'): 2,
#            ('jobs', 'but'): 3,
#            ('but', 'everybodys'): 3,
#            ('everybodys', 'got'): 44,
#            ('got', 'to'): 1228,
#            ('to', 'have'): 334,
#            ('have', 'something'): 34,
#            ('something', 'to'): 384,
#            ('to', 'do'): 1338,
#            ('do', 'with'): 189,
#            ('with', 'their'): 126,
#            ('their', 'time'): 24,
#            ('time', 'i'): 825,
#            ('wog', 'i'): 4,
#            ('dont', 'wanna'): 1170,
#            ('wanna', 'go'): 214,
#            ('go', 'home'): 164,
#            ('home', 'ive'): 20,
#            ('ive', 'got'): 1363,
#            ('got', 'a'): 1978,
#            ('a', 'lot'): 534,
#            ('lot', 'of'): 269,
#            ('of', 'life'): 360,
#            ('life', 'to'): 148,
#            ('to', 'run'): 389,
#            ('run', 'through'): 53,
#            ('through', 'i'): 70,
#            ('dont', 'mean'): 158,
#            ('mean', 'you'): 36,
#            ('you', 'no'): 239,
#            ('no', 'harm'): 24,
#            ('harm', 'just'): 2,
#            ('dont', 'ask'): 130,
#            ('ask', 'me'): 185,
#            ('me', 'to'): 1547,
#            ('to', 'shine'): 61,
#            ('shine', 'your'): 21,
#            ('your', 'shoes'): 38,
#            ('shoes', 'golly'): 2,
#            ('golly', 'gee'): 4,
#            ('gee', 'golly'): 4,
#            ('golly', 'gosh'): 4,
#            ('gosh', 'dont'): 4,
#            ('me', 'your'): 388,
#            ('your', 'golly'): 4,
#            ('golly', 'wog'): 4,
#            ('wog', 'golly'): 2,
#            ('wog', 'let'): 2,
#            ('let', 'me'): 1969,
#            ('me', 'tell'): 215,
#            ('you', 'about'): 58,
#            ('about', 'pimpo'): 2,
#            ('pimpo', 'we'): 2,
#            ('we', 'met'): 58,
#            ('met', 'him'): 13,
#            ('him', 'down'): 30,
#            ('down', 'at'): 123,
#            ('the', 'after'): 10,
#            ('after', 'eight'): 2,
#            ('eight', 'he'): 2,
#            ('he', 'wanted'): 20,
#            ('wanted', 'to'): 485,
#            ('to', 'sell'): 74,
#            ('sell', 'us'): 9,
#            ('us', 'some'): 10,
#            ('some', 'limbo'): 2,
#            ('limbo', 'but'): 2,
#            ('but', 'we'): 441,
#            ('we', 'said'): 74,
#            ('said', 'mister'): 4,
#            ('mister', 'youve'): 2,
#            ('youve', 'just'): 16,
#            ('wait', 'youve'): 3,
#            ('youve', 'got'): 869,
#            ('wait', 'x3'): 2,
#            ('x3', 'he'): 2,
#            ('to', 'take'): 896,
#            ('take', 'us'): 74,
#            ('us', 'down'): 115,
#            ('down', 'to'): 687,
#            ('to', 'sao'): 2,
#            ('sao', 'paulo'): 2,
#            ('paulo', 'but'): 2,
#            ('mister', 'we'): 2,
#            ('we', 'aint'): 111,
#            ('got', 'no'): 605,
#            ('no', 'bread'): 2,
#            ('bread', 'i'): 11,
#            ('i', 'tried'): 323,
#            ('tried', 'to'): 457,
#            ('to', 'make'): 1314,
#            ('make', 'him'): 59,
#            ('him', 'laugh'): 3,
#            ('laugh', 'but'): 22,
#            ('but', 'he'): 143,
#            ('he', 'didnt'): 28,
#            ('didnt', 'get'): 39,
#            ('get', 'the'): 368,
#            ('the', 'joke'): 11,
#            ('joke', 'and'): 9,
#            ('and', 'then'): 862,
#            ('then', 'he'): 82,
#            ('he', 'said'): 257,
#            ('said', 'i'): 286,
#            ('i', 'wasnt'): 126,
#            ('wasnt', 'right'): 7,
#            ('right', 'in'): 143,
#            ('the', 'head'): 118,
#            ('head', 'and'): 239,
#            ('he', 'made'): 20,
#            ('made', 'me'): 269,
#            ('me', 'x3'): 8,
#            ('x3', 'and'): 5,
#            ('me', 'feel'): 333,
#            ('feel', 'and'): 45,
#            ('like', 'x3'): 4,
#            ('x3', 'you'): 8,
#            ('you', 'know'): 3972,
#            ('know', 'i'): 1174,
#            ('the', 'velveteen'): 1,
#            ('velveteen', 'and'): 1,
#            ('and', 'oaken'): 1,
#            ('oaken', 'fixtures'): 1,
#            ('fixtures', 'soothed'): 1,
#            ('soothed', 'the'): 2,
#            ('the', 'lonely'): 108,
#            ('lonely', 'child'): 2,
#            ('child', 'the'): 12,
#            ('the', 'parents'): 5,
#            ('parents', 'watched'): 1,
#            ('watched', 'the'): 85,
#            ('the', 'escort'): 1,
#            ('escort', 'take'): 1,
#            ('take', 'him'): 41,
#            ('him', 'while'): 4,
#            ('while', 'they'): 28,
#            ('they', 'stood'): 4,
#            ('stood', 'outside'): 1,
#            ('outside', 'the'): 73,
#            ('the', 'priest'): 9,
#            ('priest', 'was'): 1,
#            ('was', 'kind'): 3,
#            ('kind', 'and'): 20,
#            ('and', 'gentle'): 3,
#            ('gentle', 'as'): 5,
#            ('as', 'he'): 130,
#            ('he', 'positioned'): 1,
#            ('positioned', 'his'): 1,
#            ('his', 'head'): 114,
#            ('head', 'the'): 56,
#            ('the', 'pain'): 890,
#            ('pain', 'was'): 7,
#            ('was', 'like'): 37,
#            ('like', 'brimstone'): 1,
#            ('brimstone', 'but'): 1,
#            ('but', 'the'): 755,
#            ('the', 'kid'): 36,
#            ('kid', 'hardly'): 1,
#            ('hardly', 'bled'): 1,
#            ('bled', 'victory'): 1,
#            ('victory', 'instinct'): 3,
#            ('instinct', 'over'): 3,
#            ('over', 'intellect'): 3,
#            ('intellect', 'victory'): 3,
#            ('victory', 'it'): 3,
#            ('it', 'erupts'): 3,
#            ('erupts', 'from'): 3,
#            ('from', 'deep'): 13,
#            ('deep', 'inside'): 210,
#            ('inside', 'history'): 3,
#            ('history', 'history'): 4,
#            ('history', 'is'): 21,
#            ('is', 'laughing'): 21,
#            ('laughing', 'at'): 47,
#            ('at', 'us'): 29,
#            ('us', 'plotting'): 5,
#            ('plotting', 'its'): 3,
#            ('its', 'discovery'): 3,
#            ('discovery', 'victory'): 3,
#            ('victory', 'victory'): 4,
#            ('victory', 'blame'): 3,
#            ('blame', 'it'): 47,
#            ('it', 'on'): 525,
#            ('the', 'victory'): 9,
#            ('victory', 'among'): 1,
#            ('among', 'the'): 85,
#            ('the', 'parade'): 11,
#            ('parade', 'crowd'): 1,
#            ('crowd', 'there'): 1,
#            ('there', 'stands'): 1,
#            ('stands', 'a'): 3,
#            ('a', 'decorated'): 2,
#            ('decorated', 'man'): 1,
#            ('man', 'remembering'): 1,
#            ('remembering', 'how'): 4,
#            ('how', 'he'): 41,
#            ('he', 'helped'): 5,
#            ('helped', 'to'): 4,
#            ('to', 'save'): 360,
#            ('save', 'this'): 15,
#            ('this', 'sacred'): 3,
#            ('sacred', 'land'): 1,
#            ('land', 'his'): 1,
#            ('his', 'helpless'): 1,
#            ('helpless', 'enemy'): 4,
#            ('enemy', 'was'): 2,
#            ('was', 'wounded'): 2,
#            ('wounded', 'both'): 1,
#            ('both', 'hands'): 19,
#            ('hands', 'raised'): 4,
#            ('raised', 'with'): 3,
#            ('with', 'hope'): 11,
#            ('hope', 'he'): 20,
#            ('he', 'killed'): 8,
#            ('killed', 'him'): 4,
#            ('him', 'without'): 4,
#            ('without', 'second'): 1,
#            ('second', 'thought'): 11,
#            ('thought', 'with'): 3,
#            ('with', 'brute'): 1,
#            ('brute', 'force'): 1,
#            ('force', 'and'): 1,
#            ('and', 'a'): 1049,
#            ('a', 'rope'): 31,
#            ('rope', 'victory'): 1,
#            ('victory', 'so'): 1,
#            ('so', 'many'): 490,
#            ('many', 'times'): 247,
#            ('times', 'so'): 28,
#            ('many', 'lives'): 18,
#            ('lives', 'test'): 1,
#            ('test', 'the'): 16,
#            ('the', 'other'): 521,
#            ('other', 'side'): 265,
#            ('side', 'waiting'): 1,
#            ('waiting', 'to'): 134,
#            ('to', 'see'): 1637,
#            ('see', 'what'): 336,
#            ('what', 'the'): 395,
#            ('the', 'maker'): 4,
#            ('maker', 'has'): 1,
#            ('has', 'in'): 2,
#            ('in', 'mind'): 43,
#            ('mind', 'the'): 97,
#            ('the', 'unsuspecting'): 3,
#            ('unsuspecting', 'commoners'): 1,
#            ('commoners', 'hum'): 1,
#            ('hum', 'diligent'): 1,
#            ('diligent', 'each'): 1,
#            ('each', 'day'): 77,
#            ('they', 'wallow'): 1,
#            ('wallow', 'in'): 6,
#            ('in', 'their'): 286,
#            ('their', 'fathers'): 3,
#            ('fathers', 'sins'): 1,
#            ('sins', 'as'): 4,
#            ('as', 'time'): 39,
#            ('time', 'passes'): 10,
#            ('passes', 'away'): 1,
#            ('away', 'the'): 325,
#            ('the', 'crimes'): 8,
#            ('crimes', 'are'): 6,
#            ('are', 'without'): 1,
#            ('without', 'motive'): 1,
#            ('motive', 'but'): 1,
#            ('but', 'they'): 237,
#            ('they', 'ignore'): 1,
#            ('ignore', 'all'): 8,
#            ('all', 'restraint'): 1,
#            ('restraint', 'the'): 3,
#            ('the', 'evil'): 62,
#            ('evil', 'sits'): 1,
#            ('sits', 'inside'): 2,
#            ('inside', 'them'): 1,
#            ('them', 'torpid'): 1,
#            ('torpid', 'timing'): 1,
#            ('timing', 'its'): 1,
#            ('its', 'revenge'): 1,
#            ('revenge', 'victory'): 1,
#            ('the', 'sun'): 1296,
#            ('sun', 'slips'): 4,
#            ('slips', 'through'): 5,
#            ('through', 'the'): 1425,
#            ('the', 'broken'): 111,
#            ('broken', 'blinds'): 1,
#            ('blinds', 'through'): 1,
#            ('the', 'dusty'): 6,
#            ('dusty', 'panes'): 1,
#            ('panes', 'and'): 1,
#            ('and', 'casts'): 2,
#            ('casts', 'a'): 8,
#            ('a', 'shadow'): 77,
#            ('shadow', 'across'): 1,
#            ('across', 'the'): 306,
#            ('the', 'bed'): 112,
#            ('bed', 'where'): 7,
#            ('i', 'once'): 71,
#            ('once', 'lay'): 1,
#            ('lay', 'your'): 40,
#            ('your', 'perfume'): 11,
#            ('perfume', 'lingers'): 1,
#            ('lingers', 'though'): 1,
#            ('though', 'youve'): 3,
#            ('youve', 'gone'): 80,
#            ('gone', 'my'): 22,
#            ...})},
#  'country': {'count': 4015351,
#   'prob': 0.439698702165839,
#   'word_occurence': Counter({('in', 'the'): 14971,
#            ('the', 'beginning'): 51,
#            ('beginning', 'the'): 3,
#            ('the', 'nights'): 254,
#            ('nights', 'were'): 18,
#            ('were', 'long'): 16,
#            ('long', 'under'): 2,
#            ('under', 'the'): 206,
#            ('the', 'moonlight'): 237,
#            ('moonlight', 'i'): 11,
#            ('i', 'could'): 3383,
#            ('could', 'do'): 176,
#            ('do', 'no'): 114,
#            ('no', 'wrong'): 79,
#            ('wrong', 'you'): 100,
#            ('you', 'told'): 275,
#            ('told', 'me'): 790,
#            ('me', 'i'): 2404,
#            ('i', 'was'): 5178,
#            ('was', 'everything'): 13,
#            ('everything', 'you'): 139,
#            ('you', 'wanted'): 215,
#            ('wanted', 'me'): 117,
#            ('me', 'to'): 2157,
#            ('to', 'be'): 5560,
#            ('be', 'then'): 31,
#            ('then', 'summer'): 1,
#            ('summer', 'was'): 1,
#            ('was', 'over'): 126,
#            ('over', 'and'): 487,
#            ('and', 'the'): 7302,
#            ('nights', 'grew'): 4,
#            ('grew', 'cold'): 10,
#            ('cold', 'you'): 16,
#            ('you', 'got'): 1145,
#            ('got', 'restless'): 4,
#            ('restless', 'and'): 14,
#            ('and', 'hard'): 57,
#            ('hard', 'to'): 1211,
#            ('to', 'hold'): 1067,
#            ('hold', 'i'): 25,
#            ('i', 'tried'): 463,
#            ('tried', 'to'): 810,
#            ('be', 'everything'): 26,
#            ('be', 'now'): 55,
#            ('now', 'you'): 648,
#            ('you', 'keep'): 306,
#            ('keep', 'staring'): 12,
#            ('staring', 'at'): 59,
#            ('at', 'that'): 94,
#            ('that', 'open'): 31,
#            ('open', 'door'): 52,
#            ('door', 'you'): 59,
#            ('got', 'what'): 85,
#            ('what', 'you'): 1374,
#            ('wanted', 'and'): 33,
#            ('and', 'you'): 3196,
#            ('you', 'still'): 551,
#            ('still', 'want'): 57,
#            ('want', 'more'): 31,
#            ('more', 'well'): 45,
#            ('well', 'look'): 40,
#            ('look', 'at'): 950,
#            ('at', 'me'): 644,
#            ('me', 'im'): 739,
#            ('im', 'everything'): 2,
#            ('be', 'if'): 180,
#            ('if', 'i'): 3691,
#            ('i', 'dont'): 5972,
#            ('dont', 'keep'): 58,
#            ('keep', 'you'): 259,
#            ('you', 'satisfied'): 38,
#            ('satisfied', 'you'): 10,
#            ('you', 'cant'): 1604,
#            ('cant', 'say'): 192,
#            ('say', 'that'): 881,
#            ('that', 'i'): 6002,
#            ('i', 'havent'): 229,
#            ('havent', 'tried'): 9,
#            ('tried', 'and'): 101,
#            ('and', 'if'): 1558,
#            ('if', 'im'): 397,
#            ('im', 'not'): 1550,
#            ('not', 'what'): 128,
#            ('you', 'want'): 1311,
#            ('want', 'by'): 2,
#            ('by', 'now'): 201,
#            ('now', 'for'): 122,
#            ('for', 'the'): 3897,
#            ('the', 'life'): 312,
#            ('life', 'of'): 206,
#            ('of', 'me'): 1417,
#            ('i', 'cant'): 4724,
#            ('cant', 'see'): 388,
#            ('see', 'how'): 262,
#            ('how', 'ill'): 85,
#            ('ill', 'ever'): 174,
#            ('ever', 'be'): 237,
#            ('be', 'everyhing'): 1,
#            ('everyhing', 'that'): 1,
#            ('that', 'you'): 3150,
#            ('want', 'me'): 575,
#            ('be', 'in'): 423,
#            ('wrong', 'remember'): 1,
#            ('remember', 'me'): 131,
#            ('everything', 'that'): 223,
#            ('to', 'be1'): 2,
#            ('be1', 'ill'): 2,
#            ('want', 'ill'): 18,
#            ('oh', 'break'): 1,
#            ('break', 'it'): 96,
#            ('it', 'burn'): 25,
#            ('burn', 'it'): 23,
#            ('it', 'drag'): 1,
#            ('drag', 'it'): 5,
#            ('it', 'all'): 1854,
#            ('all', 'around'): 457,
#            ('around', 'twist'): 1,
#            ('twist', 'it'): 3,
#            ('it', 'turn'): 6,
#            ('turn', 'it'): 156,
#            ('it', 'you'): 243,
#            ('cant', 'tear'): 2,
#            ('tear', 'it'): 51,
#            ('it', 'down'): 256,
#            ('down', 'cause'): 77,
#            ('cause', 'every'): 60,
#            ('every', 'minute'): 82,
#            ('minute', 'every'): 9,
#            ('every', 'hour'): 63,
#            ('hour', 'youll'): 6,
#            ('youll', 'be'): 853,
#            ('be', 'shaken'): 7,
#            ('shaken', 'by'): 7,
#            ('by', 'the'): 2412,
#            ('the', 'strength'): 87,
#            ('strength', 'and'): 30,
#            ('and', 'mighty'): 33,
#            ('mighty', 'power'): 7,
#            ('power', 'of'): 89,
#            ('of', 'my'): 2658,
#            ('my', 'love'): 1809,
#            ('love', 'crush'): 1,
#            ('crush', 'it'): 3,
#            ('it', 'kick'): 8,
#            ('kick', 'it'): 49,
#            ('you', 'can'): 3465,
#            ('can', 'never'): 183,
#            ('never', 'win'): 21,
#            ('win', 'i'): 27,
#            ('i', 'know'): 7097,
#            ('know', 'baby'): 39,
#            ('baby', 'you'): 411,
#            ('cant', 'lick'): 1,
#            ('lick', 'it'): 2,
#            ('it', 'ill'): 57,
#            ('ill', 'make'): 216,
#            ('make', 'you'): 972,
#            ('you', 'give'): 334,
#            ('give', 'in'): 124,
#            ('in', 'every'): 245,
#            ('love', 'baby'): 75,
#            ('baby', 'i'): 681,
#            ('i', 'want'): 2235,
#            ('want', 'you'): 855,
#            ('you', 'youll'): 67,
#            ('youll', 'never'): 551,
#            ('never', 'get'): 197,
#            ('get', 'away'): 175,
#            ('away', 'my'): 162,
#            ('love', 'will'): 384,
#            ('will', 'haunt'): 10,
#            ('haunt', 'you'): 10,
#            ('you', 'yes'): 188,
#            ('yes', 'haunt'): 2,
#            ('you', 'night'): 15,
#            ('night', 'and'): 729,
#            ('and', 'day'): 221,
#            ('day', 'touch'): 2,
#            ('touch', 'it'): 8,
#            ('it', 'pound'): 2,
#            ('pound', 'it'): 2,
#            ('it', 'what'): 50,
#            ('what', 'good'): 99,
#            ('good', 'does'): 10,
#            ('does', 'it'): 186,
#            ('it', 'do'): 69,
#            ('do', 'theres'): 34,
#            ('theres', 'just'): 194,
#            ('just', 'no'): 58,
#            ('no', 'stoppin'): 4,
#            ('stoppin', 'the'): 3,
#            ('the', 'way'): 4060,
#            ('way', 'i'): 1028,
#            ('i', 'feel'): 1576,
#            ('feel', 'for'): 27,
#            ('for', 'you'): 3614,
#            ('you', 'cause'): 368,
#            ('love', 'yeah'): 42,
#            ('yeah', 'yeah'): 429,
#            ('yeah', 'baby'): 49,
#            ('love', 'i'): 964,
#            ('i', 'said'): 1622,
#            ('said', 'every'): 5,
#            ('love', 'every'): 26,
#            ('they', 'say'): 879,
#            ('say', 'this'): 36,
#            ('this', 'drinkin'): 5,
#            ('drinkin', 'will'): 4,
#            ('will', 'kill'): 7,
#            ('kill', 'me'): 58,
#            ('dont', 'know'): 2325,
#            ('know', 'oh'): 80,
#            ('oh', 'lord'): 391,
#            ('lord', 'it'): 70,
#            ('it', 'might'): 207,
#            ('might', 'be'): 406,
#            ('be', 'true'): 520,
#            ('true', 'if'): 39,
#            ('i', 'stop'): 114,
#            ('stop', 'ill'): 6,
#            ('ill', 'just'): 354,
#            ('just', 'die'): 4,
#            ('die', 'from'): 25,
#            ('from', 'your'): 326,
#            ('your', 'leavin'): 19,
#            ('leavin', 'so'): 12,
#            ('so', 'either'): 15,
#            ('either', 'way'): 45,
#            ('way', 'that'): 435,
#            ('i', 'go'): 1084,
#            ('go', 'its'): 92,
#            ('its', 'cause'): 19,
#            ('cause', 'of'): 27,
#            ('of', 'you'): 1542,
#            ('you', 'death'): 2,
#            ('death', 'can'): 7,
#            ('can', 'come'): 149,
#            ('come', 'from'): 319,
#            ('from', 'this'): 191,
#            ('this', 'broken'): 66,
#            ('broken', 'heart'): 535,
#            ('heart', 'or'): 26,
#            ('or', 'it'): 32,
#            ('it', 'can'): 218,
#            ('this', 'bottle'): 26,
#            ('bottle', 'so'): 6,
#            ('so', 'why'): 162,
#            ('why', 'prolong'): 6,
#            ('prolong', 'the'): 6,
#            ('the', 'agony'): 9,
#            ('agony', 'hey'): 6,
#            ('hey', 'bartender'): 11,
#            ('bartender', 'i'): 7,
#            ('i', 'think'): 1823,
#            ('think', 'ill'): 190,
#            ('ill', 'hit'): 16,
#            ('hit', 'the'): 339,
#            ('the', 'throttle'): 29,
#            ('throttle', 'i'): 4,
#            ('dont', 'care'): 813,
#            ('care', 'how'): 38,
#            ('how', 'the'): 240,
#            ('the', 'preacher'): 130,
#            ('preacher', 'might'): 2,
#            ('might', 'preach'): 2,
#            ('preach', 'to'): 2,
#            ('to', 'me'): 4620,
#            ('me', 'about'): 95,
#            ('about', 'the'): 870,
#            ('the', 'evils'): 4,
#            ('evils', 'of'): 2,
#            ('of', 'being'): 114,
#            ('being', 'drunk'): 2,
#            ('drunk', 'with'): 2,
#            ('with', 'wine'): 10,
#            ('wine', 'i'): 36,
#            ('the', 'doctor'): 61,
#            ('doctor', 'might'): 5,
#            ('might', 'warn'): 2,
#            ('warn', 'me'): 8,
#            ('me', 'cause'): 441,
#            ('cause', 'since'): 6,
#            ('since', 'you'): 336,
#            ('you', 'left'): 652,
#            ('left', 'its'): 20,
#            ('its', 'just'): 805,
#            ('just', 'a'): 2712,
#            ('a', 'matter'): 104,
#            ('matter', 'of'): 103,
#            ('of', 'time'): 568,
#            ('time', 'death'): 2,
#            ('care', 'that'): 29,
#            ('that', 'my'): 317,
#            ('my', 'friends'): 342,
#            ('friends', 'have'): 45,
#            ('have', 'all'): 209,
#            ('all', 'left'): 13,
#            ('left', 'me'): 999,
#            ('cause', 'they'): 86,
#            ('they', 'swear'): 4,
#            ('swear', 'that'): 57,
#            ('i', 'have'): 2048,
#            ('have', 'gone'): 185,
#            ('gone', 'insane'): 13,
#            ('insane', 'and'): 18,
#            ('and', 'i'): 10998,
#            ('care', 'anymore'): 33,
#            ('anymore', 'about'): 3,
#            ('about', 'livin'): 19,
#            ('livin', 'without'): 10,
#            ('without', 'you'): 1008,
#            ('you', 'just'): 1313,
#            ('just', 'the'): 809,
#            ('the', 'grave'): 76,
#            ('grave', 'can'): 12,
#            ('can', 'ease'): 3,
#            ('ease', 'the'): 40,
#            ('the', 'pain'): 533,
#            ('pain', 'death'): 2,
#            ('throttle', 'yeah'): 2,
#            ('yeah', 'they'): 78,
#            ('you', 'either'): 12,
#            ('god', 'understands'): 6,
#            ('understands', 'he'): 4,
#            ('he', 'knows'): 229,
#            ('knows', 'all'): 26,
#            ('all', 'about'): 245,
#            ('about', 'us'): 66,
#            ('us', 'he'): 30,
#            ('knows', 'of'): 3,
#            ('of', 'our'): 376,
#            ('our', 'hopes'): 9,
#            ('hopes', 'he'): 1,
#            ('our', 'plans'): 15,
#            ('plans', 'hes'): 1,
#            ('hes', 'willing'): 1,
#            ('willing', 'to'): 92,
#            ('to', 'help'): 210,
#            ('help', 'if'): 3,
#            ('if', 'we'): 590,
#            ('we', 'will'): 226,
#            ('will', 'but'): 56,
#            ('but', 'follow'): 2,
#            ('follow', 'he'): 1,
#            ('us', 'god'): 6,
#            ('understands', 'i'): 3,
#            ('i', 'walk'): 369,
#            ('walk', 'with'): 122,
#            ('with', 'the'): 2545,
#            ('the', 'lord'): 827,
#            ('lord', 'in'): 119,
#            ('in', 'sunshine'): 47,
#            ('sunshine', 'and'): 126,
#            ('and', 'darkness'): 8,
#            ('darkness', 'i'): 24,
#            ('i', 'cannot'): 150,
#            ('cannot', 'forsake'): 1,
#            ('forsake', 'his'): 1,
#            ('his', 'word'): 34,
#            ('word', 'and'): 40,
#            ('and', 'command'): 1,
#            ('command', 'temptation'): 1,
#            ('temptation', 'is'): 2,
#            ('is', 'great'): 17,
#            ('great', 'his'): 1,
#            ('his', 'love'): 275,
#            ('love', 'is'): 1878,
#            ('is', 'still'): 270,
#            ('still', 'greater'): 1,
#            ('greater', 'he'): 1,
#            ('know', 'of'): 27,
#            ('of', 'his'): 561,
#            ('know', 'all'): 88,
#            ('all', 'its'): 105,
#            ('its', 'meaning'): 1,
#            ('meaning', 'i'): 2,
#            ('of', 'the'): 6427,
#            ('the', 'power'): 182,
#            ('power', 'hes'): 1,
#            ('hes', 'given'): 8,
#            ('given', 'to'): 11,
#            ('to', 'man'): 31,
#            ('man', 'without'): 10,
#            ('without', 'faith'): 1,
#            ('faith', 'in'): 129,
#            ('in', 'god'): 41,
#            ('god', 'my'): 9,
#            ('my', 'life'): 2321,
#            ('life', 'would'): 73,
#            ('would', 'be'): 832,
#            ('be', 'worthless'): 16,
#            ('worthless', 'he'): 1,
#            ('understands', 'when'): 1,
#            ('when', 'trouble'): 5,
#            ('trouble', 'appears'): 1,
#            ('appears', 'and'): 6,
#            ('and', 'life'): 74,
#            ('life', 'has'): 119,
#            ('has', 'no'): 81,
#            ('no', 'meaning'): 8,
#            ('meaning', 'be'): 1,
#            ('be', 'washed'): 14,
#            ('washed', 'and'): 7,
#            ('and', 'be'): 362,
#            ('be', 'cleansed'): 2,
#            ('cleansed', 'in'): 1,
#            ('the', 'blood'): 161,
#            ('blood', 'of'): 50,
#            ('the', 'lamb'): 83,
#            ('lamb', 'hes'): 1,
#            ('hes', 'trusted'): 1,
#            ('trusted', 'and'): 1,
#            ('and', 'tried'): 107,
#            ('tried', 'so'): 64,
#            ('so', 'cast'): 1,
#            ('cast', 'him'): 1,
#            ('him', 'your'): 24,
#            ('your', 'worries'): 33,
#            ('worries', 'he'): 1,
#            ('ive', 'known'): 166,
#            ('known', 'my'): 7,
#            ('my', 'share'): 98,
#            ('share', 'of'): 80,
#            ('of', 'women'): 17,
#            ('women', 'and'): 53,
#            ('and', 'their'): 124,
#            ('their', 'pleasures'): 1,
#            ('pleasures', 'ive'): 10,
#            ('ive', 'spent'): 73,
#            ('spent', 'a'): 71,
#            ('a', 'few'): 539,
#            ('few', 'cold'): 2,
#            ('cold', 'nights'): 9,
#            ('nights', 'out'): 6,
#            ('out', 'in'): 713,
#            ('the', 'rain'): 987,
#            ('rain', 'ive'): 16,
#            ('ive', 'lived'): 75,
#            ('lived', 'most'): 1,
#            ('most', 'all'): 39,
#            ('all', 'my'): 1430,
#            ('life', 'out'): 18,
#            ('out', 'on'): 789,
#            ('on', 'the'): 8840,
#            ('the', 'highway'): 317,
# ...
#            ('somebody', 'i'): 28,
#            ('i', 'want'): 1914,
#            ('want', 'a'): 175,
#            ('witness', 'is'): 2,
#            ('be', 'treated'): 10,
#            ('treated', 'so'): 6,
#            ('so', 'bad'): 228,
#            ('bad', 'when'): 21,
#            ('when', 'youve'): 24,
#            ('youve', 'given'): 54,
#            ('given', 'everything'): 4,
#            ('everything', 'you'): 111,
#            ('you', 'had'): 173,
#            ('had', 'even'): 4,
#            ('even', 'tossin'): 1,
#            ('tossin', 'in'): 1,
#            ('my', 'sleep'): 20,
#            ('sleep', 'cause'): 22,
#            ('cause', 'i'): 789,
#            ('i', 'havent'): 60,
#            ('havent', 'seen'): 15,
#            ('seen', 'my'): 23,
#            ('my', 'baby'): 1159,
#            ('baby', 'all'): 155,
#            ('all', 'week'): 16,
#            ('week', 'now'): 10,
#            ('now', 'you'): 303,
#            ('you', 'girls'): 13,
#            ('girls', 'do'): 5,
#            ('do', 'agree'): 2,
#            ('agree', 'that'): 15,
#            ('that', 'this'): 77,
#            ('this', 'aint'): 62,
#            ('aint', 'the'): 74,
#            ('the', 'way'): 1555,
#            ('way', 'loves'): 7,
#            ('loves', 'supposed'): 7,
#            ('supposed', 'to'): 94,
#            ('be', 'let'): 71,
#            ('me', 'hear'): 92,
#            ('hear', 'let'): 5,
#            ('hear', 'you'): 181,
#            ('you', 'say'): 710,
#            ('say', 'yeah'): 98,
#            ('yeah', 'yeah'): 2288,
#            ('yeah', 'up'): 7,
#            ('up', 'early'): 30,
#            ('early', 'in'): 90,
#            ('in', 'the'): 3503,
#            ('the', 'morning'): 340,
#            ('morning', 'with'): 13,
#            ('with', 'him'): 24,
#            ('him', 'on'): 2,
#            ('on', 'my'): 687,
#            ('my', 'mind'): 779,
#            ('mind', 'just'): 12,
#            ('just', 'to'): 332,
#            ('to', 'find'): 367,
#            ('find', 'out'): 100,
#            ('out', 'all'): 47,
#            ('all', 'night'): 612,
#            ('night', 'that'): 36,
#            ('that', 'ive'): 122,
#            ('ive', 'been'): 701,
#            ('been', 'cryin'): 13,
#            ('cryin', 'but'): 10,
#            ('a', 'mans'): 64,
#            ('mans', 'a'): 1,
#            ('a', 'womans'): 36,
#            ('womans', 'best'): 1,
#            ('best', 'friend'): 62,
#            ('friend', 'so'): 18,
#            ('so', 'im'): 108,
#            ('im', 'gonna'): 1237,
#            ('gonna', 'stick'): 6,
#            ('stick', 'by'): 5,
#            ('by', 'him'): 5,
#            ('him', 'till'): 6,
#            ('till', 'the'): 186,
#            ('the', 'very'): 82,
#            ('very', 'end'): 5,
#            ('end', 'but'): 24,
#            ('but', 'he'): 60,
#            ('he', 'causes'): 1,
#            ('causes', 'so'): 5,
#            ('much', 'misery'): 5,
#            ('misery', 'i'): 15,
#            ('i', 'forget'): 27,
#            ('forget', 'how'): 11,
#            ('how', 'love'): 29,
#            ('is', 'supposed'): 7,
#            ('be', 'somebody'): 6,
#            ('him', 'it'): 4,
#            ('it', 'aint'): 468,
#            ('aint', 'fair'): 22,
#            ('fair', 'can'): 5,
#            ('witness', 'i'): 19,
#            ('witness', 'everybody'): 6,
#            ('everybody', 'knows'): 49,
#            ('knows', 'especially'): 5,
#            ('girls', 'love'): 1,
#            ('love', 'can'): 197,
#            ('can', 'be'): 558,
#            ('be', 'bad'): 18,
#            ('bad', 'but'): 11,
#            ('i', 'have'): 728,
#            ('have', 'a'): 439,
#            ('a', 'love'): 446,
#            ('love', 'thats'): 166,
#            ('thats', 'twice'): 1,
#            ('twice', 'as'): 30,
#            ('as', 'bad'): 16,
#            ('bad', 'now'): 21,
#            ('yeah', 'can'): 33,
#            ('i', 'cant'): 1793,
#            ('cant', 'stand'): 226,
#            ('stand', 'the'): 77,
#            ('the', 'rain'): 230,
#            ('rain', 'against'): 45,
#            ('against', 'my'): 54,
#            ('my', 'window'): 102,
#            ('window', 'bringing'): 25,
#            ('bringing', 'back'): 29,
#            ('back', 'sweet'): 25,
#            ('sweet', 'memories'): 56,
#            ('memories', 'i'): 31,
#            ('window', 'cause'): 20,
#            ('cause', 'he'): 46,
#            ('he', 'aint'): 65,
#            ('aint', 'here'): 21,
#            ('here', 'with'): 159,
#            ('with', 'me'): 1172,
#            ('me', 'hey'): 64,
#            ('hey', 'window'): 5,
#            ('window', 'pane'): 36,
#            ('pane', 'do'): 5,
#            ('do', 'you'): 1061,
#            ('you', 'remember'): 112,
#            ('remember', 'how'): 34,
#            ('how', 'sweet'): 54,
#            ('it', 'used'): 24,
#            ('used', 'to'): 525,
#            ('be', 'when'): 30,
#            ('when', 'we'): 327,
#            ('we', 'were'): 205,
#            ('were', 'together'): 48,
#            ('together', 'everything'): 15,
#            ('everything', 'was'): 29,
#            ('was', 'so'): 123,
#            ('so', 'grand'): 21,
#            ('grand', 'now'): 10,
#            ('now', 'that'): 266,
#            ('that', 'weve'): 40,
#            ('weve', 'parted'): 10,
#            ('parted', 'theres'): 10,
#            ('theres', 'one'): 52,
#            ('one', 'sound'): 10,
#            ('sound', 'that'): 19,
#            ('that', 'i'): 1939,
#            ('i', 'just'): 1055,
#            ('just', 'cant'): 343,
#            ('stand', 'i'): 22,
#            ('theres', 'just'): 33,
#            ('just', 'one'): 166,
#            ('one', 'thing'): 183,
#            ('thing', 'that'): 135,
#            ('rain', 'i'): 35,
#            ('grand', 'yeah'): 5,
#            ('yeah', 'i'): 431,
#            ('know', 'you'): 839,
#            ('you', 'got'): 1017,
#            ('got', 'some'): 172,
#            ('some', 'sweet'): 18,
#            ('memories', 'but'): 6,
#            ('but', 'theres'): 61,
#            ('window', 'it'): 9,
#            ('just', 'keeps'): 34,
#            ('keeps', 'on'): 24,
#            ('on', 'haunting'): 5,
#            ('haunting', 'me'): 21,
#            ('hey', 'hey'): 1015,
#            ('hey', 'get'): 16,
#            ('get', 'off'): 121,
#            ('off', 'of'): 82,
#            ('of', 'my'): 994,
#            ('and', 'i'): 2677,
#            ('you', 'bout'): 27,
#            ('bout', 'a'): 49,
#            ('a', 'girl'): 281,
#            ('girl', 'i'): 380,
#            ('know', 'she'): 41,
#            ('she', 'is'): 35,
#            ('is', 'my'): 270,
#            ('baby', 'and'): 322,
#            ('and', 'she'): 125,
#            ('she', 'lives'): 3,
#            ('lives', 'next'): 1,
#            ('next', 'door'): 18,
#            ('door', 'every'): 4,
#            ('every', 'morning'): 45,
#            ('morning', 'fore'): 4,
#            ('fore', 'the'): 4,
#            ('the', 'sun'): 486,
#            ('sun', 'comes'): 17,
#            ('comes', 'up'): 18,
#            ('up', 'she'): 9,
#            ('she', 'brings'): 12,
#            ('brings', 'my'): 1,
#            ('my', 'coffee'): 11,
#            ('coffee', 'in'): 13,
#            ('my', 'favorite'): 27,
#            ('favorite', 'cup'): 4,
#            ('cup', 'thats'): 4,
#            ('why', 'i'): 300,
#            ('know', 'yeah'): 27,
#            ('know', 'hallelujah'): 16,
#            ('hallelujah', 'i'): 23,
#            ('just', 'love'): 82,
#            ('love', 'her'): 175,
#            ('her', 'so'): 46,
#            ('so', 'when'): 45,
#            ('im', 'in'): 503,
#            ('in', 'trouble'): 91,
#            ('trouble', 'and'): 16,
#            ('have', 'no'): 130,
#            ('no', 'friends'): 13,
#            ('friends', 'i'): 18,
#            ('know', 'shell'): 6,
#            ('shell', 'stick'): 1,
#            ('stick', 'with'): 5,
#            ('me', 'until'): 24,
#            ('until', 'the'): 223,
#            ('the', 'end'): 214,
#            ('end', 'everybody'): 4,
#            ('everybody', 'asks'): 3,
#            ('asks', 'me'): 6,
#            ('me', 'how'): 196,
#            ('know', 'i'): 1026,
#            ('i', 'smile'): 16,
#            ('smile', 'at'): 18,
#            ('at', 'them'): 7,
#            ('them', 'and'): 31,
#            ('and', 'say'): 99,
#            ('say', 'she'): 11,
#            ('she', 'told'): 51,
#            ('told', 'me'): 344,
#            ('so', 'thats'): 12,
#            ('i', 'call'): 81,
#            ('call', 'her'): 36,
#            ('her', 'on'): 40,
#            ('the', 'telephone'): 47,
#            ('telephone', 'tell'): 3,
#            ('tell', 'her'): 107,
#            ('her', 'that'): 92,
#            ('that', 'im'): 385,
#            ('im', 'all'): 102,
#            ('all', 'alone'): 276,
#            ('alone', 'by'): 13,
#            ('by', 'the'): 373,
#            ('the', 'time'): 714,
#            ('i', 'count'): 17,
#            ('count', 'from'): 8,
#            ('from', 'one'): 29,
#            ('one', 'to'): 130,
#            ('to', 'four'): 14,
#            ('four', 'i'): 12,
#            ('i', 'hear'): 244,
#            ('hear', 'her'): 34,
#            ('my', 'door'): 62,
#            ('door', 'in'): 13,
#            ('the', 'evening'): 76,
#            ('evening', 'when'): 21,
#            ('when', 'the'): 538,
#            ('sun', 'does'): 2,
#            ('does', 'down'): 2,
#            ('there', 'is'): 292,
#            ('is', 'nobody'): 11,
#            ('around', 'she'): 10,
#            ('she', 'kisses'): 9,
#            ('kisses', 'me'): 9,
#            ('she', 'holds'): 4,
#            ('holds', 'me'): 7,
#            ('me', 'tight'): 89,
#            ('tight', 'and'): 47,
#            ('and', 'tells'): 16,
#            ('tells', 'me'): 70,
#            ('me', 'stevie'): 2,
#            ('stevie', 'everythings'): 2,
#            ('everythings', 'all'): 8,
#            ('all', 'right'): 976,
#            ('right', 'thats'): 10,
#            ('so', 'hallelujah'): 2,
#            ('remember', 'when'): 85,
#            ('i', 'met'): 116,
#            ('met', 'you'): 93,
#            ('you', 'baby'): 1277,
#            ('baby', 'you'): 543,
#            ('you', 'were'): 683,
#            ('were', 'on'): 18,
#            ('on', 'your'): 439,
#            ('your', 'way'): 136,
#            ('way', 'to'): 246,
#            ('be', 'wed'): 6,
#            ('wed', 'you'): 3,
#            ('were', 'such'): 6,
#            ('such', 'a'): 318,
#            ('a', 'sexy'): 23,
#            ('sexy', 'thing'): 4,
#            ('thing', 'i'): 164,
#            ('i', 'loved'): 75,
#            ('loved', 'the'): 9,
#            ('way', 'you'): 467,
#            ('you', 'walked'): 57,
#            ('walked', 'the'): 5,
#            ('the', 'things'): 418,
#            ('things', 'you'): 192,
#            ('you', 'said'): 231,
#            ('said', 'i'): 216,
#            ('i', 'was'): 1066,
#            ('so', 'nonchalant'): 3,
#            ('nonchalant', 'i'): 3,
#            ('i', 'didnt'): 319,
#            ('didnt', 'want'): 41,
#            ('want', 'you'): 831,
#            ('you', 'to'): 822,
#            ('be', 'misled'): 8,
#            ('misled', 'but'): 4,
#            ('i', 'got'): 1379,
#            ('to', 'have'): 369,
#            ('have', 'you'): 270,
#            ('my', 'bed'): 25,
#            ('bed', 'you'): 4,
#            ('said', 'im'): 49,
#            ('im', 'just'): 348,
#            ('just', 'a'): 986,
#            ('a', 'virgin'): 25,
#            ('virgin', 'and'): 3,
#            ('and', 'im'): 601,
#            ('im', 'on'): 98,
#            ('my', 'way'): 268,
#            ('wed', 'but'): 3,
#            ('but', 'youre'): 109,
#            ('youre', 'such'): 27,
#            ('a', 'hunk'): 4,
#            ('hunk', 'so'): 3,
#            ('so', 'full'): 10,
#            ('full', 'of'): 201,
#            ('of', 'spunk'): 3,
#            ('spunk', 'ill'): 3,
#            ('ill', 'give'): 100,
#            ('give', 'you'): 362,
#            ('you', 'head'): 12,
#            ('head', 'till'): 28,
#            ('till', 'youre'): 36,
#            ('youre', 'burning'): 9,
#            ('burning', 'up'): 14,
#            ('up', 'head'): 9,
#            ('till', 'you'): 262,
#            ('you', 'get'): 591,
#            ('get', 'enough'): 241,
#            ('enough', 'head'): 9,
#            ('till', 'your'): 40,
#            ('your', 'love'): 1528,
#            ('is', 'red'): 16,
#            ('red', 'head'): 9,
#            ('head', 'love'): 9,
#            ('you', 'till'): 68,
#            ('youre', 'dead'): 17,
#            ('dead', 'you'): 6,
#            ('you', 'know'): 2897,
#            ('youre', 'good'): 15,
#            ('good', 'girl'): 29,
#            ('i', 'think'): 598,
#            ('think', 'you'): 112,
#            ('you', 'like'): 436,
#            ('like', 'to'): 298,
#            ('to', 'go'): 507,
#            ('go', 'down'): 74,
#            ('down', 'you'): 66,
#            ('you', 'wouldnt'): 33,
#            ('wouldnt', 'have'): 21,
#            ('have', 'stopped'): 6,
#            ('stopped', 'but'): 3,
#            ('i', 'came'): 43,
#            ('came', 'on'): 14,
#            ('on', 'getting'): 4,
#            ('getting', 'down'): 17,
#            ('i', 'must'): 162,
#            ('must', 'confess'): 26,
#            ('confess', 'i'): 9,
#            ('want', 'to'): 1231,
#            ('to', 'get'): 775,
#            ('get', 'undressed'): 4,
#            ('undressed', 'and'): 3,
#            ('and', 'go'): 91,
#            ('go', 'to'): 242,
#            ('to', 'bed'): 14,
#            ('bed', 'with'): 13,
#            ('with', 'that'): 56,
#            ('i', 'changed'): 10,
#            ('changed', 'you'): 6,
#            ('you', 'fool'): 19,
#            ('fool', 'you'): 49,
#            ('you', 'married'): 7,
#            ('married', 'me'): 3,
#            ('me', 'instead'): 6,
#            ('instead', 'now'): 3,
#            ('now', 'morning'): 3,
#            ('morning', 'noon'): 20,
#            ('noon', 'and'): 22,
#            ('and', 'night'): 161,
#            ('night', 'i'): 176,
#            ('i', 'give'): 123,
#            ('dead', 'ooh'): 3,
#            ('ooh', 'yeah'): 171,
#            ('yeah', 'ooh'): 79,
#            ('yeah', 'head'): 3,
#            ('head', 'head'): 12,
#            ('head', 'ooh'): 12,
#            ('ooh', 'ah'): 36,
#            ('ah', 'head'): 3,
#            ('dead', 'i'): 10,
#            ('know', 'head'): 6,
#            ('head', 'i'): 23,
#            ('head', 'baby'): 5,
#            ('baby', 'baby'): 1419,
#            ('baby', 'head'): 3,
#            ('ooh', 'head'): 9,
#            ('head', 'you'): 7,
#            ('you', 'just'): 594,
#            ('just', 'said'): 6,
#            ('i', 'could'): 670,
#            ('could', 'head'): 3,
#            ('head', 'im'): 3,
#            ('im', 'good'): 8,
#            ('good', 'head'): 5,
#            ('if', 'you'): 2447,
#            ('had', 'a'): 352,
#            ('a', 'choice'): 21,
#            ('choice', 'of'): 17,
#            ('of', 'colors'): 14,
#            ('colors', 'which'): 14,
#            ('which', 'one'): 26,
#            ('one', 'would'): 33,
#            ('would', 'you'): 269,
#            ('you', 'choose'): 52,
#            ('choose', 'my'): 15,
#            ('my', 'brothers'): 30,
#            ('brothers', 'if'): 13,
#            ('if', 'there'): 38,
#            ('there', 'was'): 207,
#            ('was', 'no'): 55,
#            ('no', 'day'): 11,
#            ('day', 'or'): 22,
#            ('or', 'night'): 19,
#            ('night', 'which'): 11,
#            ('which', 'would'): 11,
#            ('you', 'prefer'): 12,
#            ('prefer', 'to'): 12,
#            ('be', 'right'): 147,
#            ('right', 'how'): 7,
#            ('long', 'have'): 11,
#            ('you', 'hated'): 10,
#            ('hated', 'your'): 10,
#            ('your', 'white'): 10,
#            ('white', 'teacher'): 10,
#            ('teacher', 'who'): 10,
#            ('who', 'told'): 17,
#            ('told', 'you'): 214,
#            ('you', 'you'): 760,
#            ('love', 'your'): 157,
#            ('your', 'black'): 10,
#            ('black', 'preacher'): 10,
#            ('preacher', 'do'): 5,
#            ('you', 'respect'): 10,
#            ('respect', 'your'): 11,
#            ('your', 'brothers'): 16,
#            ('brothers', 'woman'): 10,
#            ('woman', 'friend'): 10,
#            ('friend', 'and'): 28,
#            ('and', 'share'): 25,
#            ('share', 'with'): 25,
#            ('with', 'black'): 10,
#            ('black', 'folks'): 10,
#            ('folks', 'not'): 10,
#            ('not', 'of'): 19,
#            ('of', 'kin'): 18,
#            ...})}}

# %% [markdown]
# ### **Step 3: Implementing Naive Bayes**

# %%
# Since by multiplying too many small probability, the result will become 0
# Therefore, we will use log2 function to avoid this situtation

# Parameters for Laplace smoothing
alpha = 1
K = len(word_vocab)

# Log prob of the lyric belong to a given genre = sum of prob of each word belong to that genre
def prob_log2_lyric_in_genre(lyric_words, genre):
  prob_lyric = 0
  for word in lyric_words:
    # for word not in the vocab, it would be much easier just to drop it (log prop = 0)
    if word in word_vocab:
      # using Laplace smoothing with number of features = number of word in vocab
      prob_lyric += np.log2(genre_data[genre]['word_occurence'][word] + alpha) - np.log2(genre_data[genre]['count'] + alpha * K)
  return prob_lyric

# %%
def genre_prediction(lyric_words):
  max = -1000000000000000000000
  for genre in genres:
    prob_log2 = prob_log2_lyric_in_genre(lyric_words, genre) + np.log2(genre_data[genre]['prob'])
    if prob_log2 > max:
      max = prob_log2
      genre_return = genre
  return genre_return

# %% [markdown]
# ### **Step 4: Testing**

# %%
test_dataframe
# Out:
#                                     song  ...                                        lyric_words
# 0                                  Maria  ...  [(she, moves), (moves, like), (like, she), (sh...
# 1                  Angel from Montgomery  ...  [(i, am), (am, an), (an, old), (old, woman), (...
# 2                             Good Times  ...  [(when, i), (i, ran), (ran, to), (to, the), (t...
# 3                  Hawaiian Wedding Song  ...  [(this, is), (is, the), (the, moment), (moment...
# 4                        Full Disclosure  ...  [(oh, i), (i, dont), (dont, want), (want, one)...
# ...                                  ...  ...                                                ...
# 11978                       I. Pink Toes  ...  [(rainbows, sunshine), (sunshine, everywhere),...
# 11979                          Millyrokk  ...  [(no, ceilings), (ceilings, no), (no, ceilings...
# 11980  Still Crazy After All These Years  ...  [(i, met), (met, my), (my, old), (old, lover),...
# 11981               Let's Do It For Love  ...  [(i, love), (love, you), (you, with), (with, e...
# 11982  That's All That's Left of My Baby  ...  [(walter, hayness), (hayness, lorene), (lorene...
#
# [11983 rows x 5 columns]

# %%
test_dataframe['predicted'] = test_dataframe['lyric_words'].apply(genre_prediction)
test_dataframe
# Out:
#                                     song  ... predicted
# 0                                  Maria  ...  alt rock
# 1                  Angel from Montgomery  ...   country
# 2                             Good Times  ...   country
# 3                  Hawaiian Wedding Song  ...   country
# 4                        Full Disclosure  ...  alt rock
# ...                                  ...  ...       ...
# 11978                       I. Pink Toes  ...   country
# 11979                          Millyrokk  ...   hip hop
# 11980  Still Crazy After All These Years  ...   country
# 11981               Let's Do It For Love  ...   country
# 11982  That's All That's Left of My Baby  ...   country
#
# [11983 rows x 6 columns]

# %%
correct = (test_dataframe['predicted'] == test_dataframe['ranker_genre']).sum() / test_dataframe.shape[0] * 100
print(correct)
test_dataframe['predicted'] == test_dataframe['ranker_genre']
# Out:
# 83.12609530167737
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 11978    False
# 11979     True
# 11980    False
# 11981    False
# 11982     True
# Length: 11983, dtype: bool
